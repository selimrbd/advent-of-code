# %% [markdown]
# # Day 2 - AoC 2024

# %% [markdown]
# [LINK](https://adventofcode.com/2024/day/2)

# %%
YEAR = 2024
DAY = 2

from aocd import get_data
import sys
import os
sys.path.append("..")
from config import load_config
load_config()
data = get_data(year=YEAR, day=DAY)
#print(os.getenv('AOC_SESSION'))

DEBUG = True

# %% [markdown]
# # Part 1

# %% [markdown]
# ## problem statement

# %% [markdown]
# The unusual data (your puzzle input) consists of many reports, one report per line. Each report is a list of numbers called levels that are separated by spaces. For example:

# %%
samp = """7 6 4 2 1
1 2 7 8 9
9 7 6 2 1
1 3 2 4 5
8 6 4 4 1
1 3 6 7 9
"""

# %% [markdown]
# This example data contains six reports each containing five levels.
#
# The engineers are trying to figure out which reports are safe. The Red-Nosed reactor safety systems can only tolerate levels that are either gradually increasing or gradually decreasing. So, a report only counts as safe if both of the following are true:
#
# The levels are either all increasing or all decreasing.
# Any two adjacent levels differ by at least one and at most three.
# In the example above, the reports can be found safe or unsafe by checking those rules:
#
# - 7 6 4 2 1: Safe because the levels are all decreasing by 1 or 2.
# - 1 2 7 8 9: Unsafe because 2 7 is an increase of 5.
# - 9 7 6 2 1: Unsafe because 6 2 is a decrease of 4.
# - 1 3 2 4 5: Unsafe because 1 3 is increasing but 3 2 is decreasing.
# - 8 6 4 4 1: Unsafe because 4 4 is neither an increase or a decrease.
# - 1 3 6 7 9: Safe because the levels are all increasing by 1, 2, or 3.
#
# So, in this example, 2 reports are safe.
#
# Analyze the unusual data from the engineers. How many reports are safe?

# %% [markdown]
# ## Try 1

# %%
def line_to_list(line: str) -> list[int]:
    ...

# %%
line = "7 6 4 2 1"
line.split(' ')
# Out:
# ['7', '6', '4', '2', '1']

# %%
[int(s) for s in line.split(' ')]
# Out:
# [7, 6, 4, 2, 1]

# %%
def line_to_list(line: str) -> list[int]:
    return [int(s) for s in line.split(' ')]

# %%
line = "7 6 4 2 1"
l_int = line_to_list(line)
l_int
# Out:
# [7, 6, 4, 2, 1]

# %%
for i in range(len(l_int)-1):
    print(l_int[i], l_int[i+1])
# Out:
# 7 6
# 6 4
# 4 2
# 2 1

# %%
[l_int[i] - l_int[i+1] for i in range(len(l_int)-1)]
# Out:
# [1, 2, 2, 1]

# %% [markdown]
# Actually instead of computing it for all the list, I want to stop as soon as I detect that the list is unsafe.
#
# So instead of list comprehensions, let's use a while loop

# %%
def ints_order(int1, int2) -> int:
    """1 if int2 >= int1, -1 otherwise"""
    if int2 >= int1:
        return 1 
    else:
        return -1

# %%
def is_report_safe(report: list[int]) -> bool:
    ...

# %%
report = line_to_list(line)
order = ints_order(report[0],report[1])
safe = True
i = 1
while i < (len(report) - 1):
    int1 = report[i]
    int2 = report[i+1]
    diff = abs(int1 - int2) 
    
    fail1 = ints_order(int1, int2) != order
    fail2 = diff < 1 or diff > 3 
    if fail1 or fail2:
        safe = False
        break
    i += 1
print(safe)
# Out:
# True

# %%
def is_report_safe(report: list[int], debug: bool = DEBUG) -> bool:
    
    safe = True
    if debug: 
        print(report)
    order = ints_order(report[0],report[1])
    i = 0
    
    while i < (len(report) - 1):
        int1 = report[i]
        int2 = report[i+1]
        diff = abs(int1 - int2) 
        
        fail1 = ints_order(int1, int2) != order
        fail2 = diff < 1 or diff > 3 
        if fail1 or fail2:
            
            safe = False
            break
        i += 1
    
    if debug:
        if safe:
            print('safe')
        else:
            print(f'i = {i}, int1 = {int1}, int2 = {int2} (fail order = {fail1}, fail diff = {fail2})')
        print('-'*50)
    return safe

# %%
line = "7 6 4 2 1"
report = line_to_list(line)
is_report_safe(report)
# Out:
# True

# %%
line = "1 2 7 8 9"
report = line_to_list(line)
is_report_safe(report)
# Out:
# False

# %%
line = "8 6 4 4 1"
report = line_to_list(line)
is_report_safe(report)
# Out:
# False

# %%
line = "1 3 6 7 9"
report = line_to_list(line)
is_report_safe(report)
# Out:
# True

# %%
def sol_2024_2_1(dat: str) -> int:
    ...

# %%
dat = samp 
nb_safe = 0
lines = dat.splitlines()
print(lines)
# Out:
# ['7 6 4 2 1', '1 2 7 8 9', '9 7 6 2 1', '1 3 2 4 5', '8 6 4 4 1', '1 3 6 7 9']

# %%
reports_safe = [is_report_safe(line_to_list(l)) for l in lines]
reports_safe
# Out:
# [True, False, False, False, False, True]

# %%
sum(reports_safe)
# Out:
# 2

# %%
def sol_2024_2_1(dat: str) -> int:
    lines = dat.splitlines()
    reports_safe = [is_report_safe(line_to_list(l)) for l in lines]
    return sum(reports_safe)

# %%
dat = samp
sol_2024_2_1(dat)
# Out:
# 2

# %%
dat = data
sol_2024_2_1(dat)
# Out:
# 598

# %% [markdown]
# My answer is too high, meaning we are deeming as safe reports that aren't/
#
# let's inspect all lists that were deemed safe.

# %%
dat = data
lines = dat.splitlines()

# %%
nb_reports = len(lines)
nb_reports
# Out:
# 1000

# %%
reports_safe = [line_to_list(l) for l in lines if is_report_safe(line_to_list(l), debug=False)]

# %% [markdown]
# let's check the length of each successful report

# %%
min([len(report) for report in reports_safe])
# Out:
# 5

# %%
max([len(report) for report in reports_safe])
# Out:
# 8

# %%
min([i for report in reports_safe for i in report])
# Out:
# 1

# %%
max([i for report in reports_safe for i in report])
# Out:
# 99

# %%
len(samp.splitlines())
# Out:
# 6

# %%
len(data.splitlines())
# Out:
# 1000

# %%
min([i for l in lines for i in line_to_list(l)])
# Out:
# 1

# %%
max([i for l in lines for i in line_to_list(l)])
# Out:
# 99

# %%
def line_to_list(line: str) -> list[int]:
    return [int(s) for s in line.split(' ')]


def ints_order(int1, int2) -> int:
    """1 if int2 >= int1, -1 otherwise"""
    if int2 >= int1:
        return 1 
    else:
        return -1
    
    
def is_report_safe(report: list[int], debug: bool = DEBUG) -> bool:
    
    safe = True
    if debug: 
        print(report)
    order = ints_order(report[0],report[1])
    i = 0
    
    while i < (len(report) - 1):
        int1 = report[i]
        int2 = report[i+1]
        diff = abs(int1 - int2) 
        
        fail1 = ints_order(int1, int2) != order
        fail2 = diff < 1 or diff > 3 
        if fail1 or fail2:
            
            safe = False
            break
        i += 1
    
    if debug:
        if safe:
            print('safe')
        else:
            print(f'i = {i}, int1 = {int1}, int2 = {int2} (fail order = {fail1}, fail diff = {fail2})')
        print('-'*50)
    return safe 


def sol_2024_2_1(dat: str) -> int:
    lines = dat.splitlines()
    reports_safe = [is_report_safe(line_to_list(l)) for l in lines]
    return sum(reports_safe)

# %% [markdown]
# ... I had to start from i = 0
#
# (before put i = 1, so was considering "safe" reports that weren't)

# %% [markdown]
# # Part 2

# %% [markdown]
# ## problem statement

# %% [markdown]
# The engineers are surprised by the low number of safe reports until they realize they forgot to tell you about the Problem Dampener.
#
# The Problem Dampener is a reactor-mounted module that lets the reactor safety systems tolerate a single bad level in what would otherwise be a safe report. It's like the bad level never happened!
#
# Now, the same rules apply as before, except if removing a single level from an unsafe report would make it safe, the report instead counts as safe.
#
# More of the above example's reports are now safe:
#
# - 7 6 4 2 1: Safe without removing any level.
# - 1 2 7 8 9: Unsafe regardless of which level is removed.
# - 9 7 6 2 1: Unsafe regardless of which level is removed.
# - 1 3 2 4 5: Safe by removing the second level, 3.
# - 8 6 4 4 1: Safe by removing the third level, 4.
# - 1 3 6 7 9: Safe without removing any level.
#
# Thanks to the Problem Dampener, 4 reports are actually safe!
#
# Update your analysis by handling situations where the Problem Dampener can remove a single level from unsafe reports. How many reports are now safe?

# %% [markdown]
# ## try

# %%
## identical functions
def line_to_list(line: str) -> list[int]:
    return [int(s) for s in line.split(' ')]


def ints_order(int1, int2) -> int:
    """1 if int2 >= int1, -1 otherwise"""
    if int2 >= int1:
        return 1 
    else:
        return -1

# %% [markdown]
# we need to modoify is_report_safe

# %%
line = "1 3 2 4 5"
report = line_to_list(line)
print(report)
# Out:
# [1, 3, 2, 4, 5]

# %% [markdown]
# When a couple of ints is unsafe, you try removing either one or the other
#
# 1) If you remove the one on the left:
#
# - check if the one before and the right one is a valid couple
# - index doesn't need modification
#
# 2) If you remove the one on the right:
#
# - check if left one and one after the right one is valid
# - index needs to be bumped by one
#
# 3) Special case: if left one is the first one:
# - only check if the diff is correct + recompute initial order

# %% [markdown]
# BETTER:
#
# - if the report fails, we ADD 2 new reports to check:
# - the one without the left element
# - the one without the right element
#
# if at least one of them is correct: we deem the report as correct, otherwise incorrect.
#
# - let's keep as is is_report_safe for strict checking, and make a _tolerate version

# %%
def remove_element(report: list[int], i: int) -> list[int]:
    return report[0:i] + report[(i+1):]

# %%
a = [1,2,3,4]
i = 2
remove_element(a, i)
# Out:
# [1, 2, 4]

# %%
def is_report_safe_tolerate(report: list[int], strict: bool = False, debug: bool = DEBUG) -> bool:

    safe = True
    order = ints_order(report[0],report[1])
    i = 0
    
    while i < (len(report) - 1):
        int1 = report[i]
        int2 = report[i+1]
        diff = abs(int1 - int2) 
         
        fail1 = ints_order(int1, int2) != order
        fail2 = diff < 1 or diff > 3 
        if fail1 or fail2:
            if strict:
                safe = False
                break
            r1 = remove_element(report, i)
            r2 = remove_element(report, i+1)
            remove_is_safe = is_report_safe_tolerate(r1, strict=True, debug=False) or is_report_safe_tolerate(r2, strict=True, debug=False)
            if remove_is_safe: 
                safe = True
                break
            else:
                safe = False 
                break    
        i += 1
    
    if not safe and debug:
        print(report)
        print(f'i = {i}, int1 = {int1}, int2 = {int2} (fail order = {fail1}, fail diff = {fail2})')
        print('-'*50)

    return safe

# %%
def sol_2024_2_2(dat: str) -> int:
    lines = dat.splitlines()
    reports_safe = [is_report_safe_tolerate(line_to_list(l)) for l in lines]
    return sum(reports_safe)

# %%
dat = samp 
sol_2024_2_2(dat)
# Out:
# [1, 2, 7, 8, 9]
# i = 1, int1 = 2, int2 = 7 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 7, 6, 2, 1]
# i = 2, int1 = 6, int2 = 2 (fail order = False, fail diff = True)
# --------------------------------------------------
# 4

# %%
dat = data 
sol_2024_2_2(dat)

## 631: the answer is too low
# Out:
# [95, 97, 98, 99, 98, 99]
# i = 3, int1 = 99, int2 = 98 (fail order = True, fail diff = False)
# --------------------------------------------------
# [84, 85, 88, 89, 88, 85]
# i = 3, int1 = 89, int2 = 88 (fail order = True, fail diff = False)
# --------------------------------------------------
# [20, 23, 21, 24, 25, 28, 31, 31]
# i = 1, int1 = 23, int2 = 21 (fail order = True, fail diff = False)
# --------------------------------------------------
# [15, 16, 18, 17, 18, 22]
# i = 2, int1 = 18, int2 = 17 (fail order = True, fail diff = False)
# --------------------------------------------------
# [31, 32, 30, 32, 34, 39]
# i = 1, int1 = 32, int2 = 30 (fail order = True, fail diff = False)
# --------------------------------------------------
# [2, 4, 4, 5, 8, 9, 6]
# i = 1, int1 = 4, int2 = 4 (fail order = False, fail diff = True)
# --------------------------------------------------
# [68, 69, 72, 72, 72]
# i = 2, int1 = 72, int2 = 72 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 74, 77, 77, 80, 82, 83, 87]
# i = 2, int1 = 77, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [11, 13, 15, 16, 16, 17, 23]
# i = 3, int1 = 16, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 74, 78, 81, 84]
# i = 1, int1 = 74, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [51, 52, 54, 58, 59, 56]
# i = 2, int1 = 54, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 42, 46, 48, 51, 53, 53]
# i = 1, int1 = 42, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [18, 19, 20, 21, 25, 29]
# i = 3, int1 = 21, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 22, 23, 27, 28, 31, 38]
# i = 2, int1 = 23, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [3, 5, 8, 9, 14, 15]
# i = 3, int1 = 9, int2 = 14 (fail order = False, fail diff = True)
# --------------------------------------------------
# [1, 4, 5, 6, 13, 12]
# i = 3, int1 = 6, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 51, 57, 59, 60, 60]
# i = 1, int1 = 51, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [42, 45, 48, 54, 57, 61]
# i = 2, int1 = 48, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [17, 20, 23, 24, 29, 31, 37]
# i = 3, int1 = 24, int2 = 29 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 49, 50, 51, 52, 54, 55]
# i = 1, int1 = 49, int2 = 50 (fail order = True, fail diff = False)
# --------------------------------------------------
# [9, 7, 8, 10, 13, 16, 15]
# i = 1, int1 = 7, int2 = 8 (fail order = True, fail diff = False)
# --------------------------------------------------
# [16, 14, 17, 18, 18]
# i = 1, int1 = 14, int2 = 17 (fail order = True, fail diff = False)
# --------------------------------------------------
# [49, 47, 50, 53, 55, 59]
# i = 1, int1 = 47, int2 = 50 (fail order = True, fail diff = False)
# --------------------------------------------------
# [21, 20, 23, 26, 27, 30, 35]
# i = 1, int1 = 20, int2 = 23 (fail order = True, fail diff = False)
# --------------------------------------------------
# [78, 77, 78, 81, 84, 82, 85, 86]
# i = 1, int1 = 77, int2 = 78 (fail order = True, fail diff = False)
# --------------------------------------------------
# [94, 91, 94, 93, 96, 93]
# i = 1, int1 = 91, int2 = 94 (fail order = True, fail diff = False)
# --------------------------------------------------
# [13, 12, 14, 12, 13, 13]
# i = 1, int1 = 12, int2 = 14 (fail order = True, fail diff = False)
# --------------------------------------------------
# [19, 17, 18, 20, 19, 23]
# i = 1, int1 = 17, int2 = 18 (fail order = True, fail diff = False)
# --------------------------------------------------
# [57, 54, 57, 55, 57, 64]
# i = 1, int1 = 54, int2 = 57 (fail order = True, fail diff = False)
# --------------------------------------------------
# [86, 84, 84, 85, 88]
# i = 1, int1 = 84, int2 = 84 (fail order = True, fail diff = True)
# --------------------------------------------------
# [16, 14, 14, 16, 15]
# i = 1, int1 = 14, int2 = 14 (fail order = True, fail diff = True)
# --------------------------------------------------
# [74, 72, 74, 74, 77, 79, 80, 80]
# i = 1, int1 = 72, int2 = 74 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 48, 49, 49, 53]
# i = 1, int1 = 48, int2 = 49 (fail order = True, fail diff = False)
# --------------------------------------------------
# [26, 24, 27, 29, 30, 33, 33, 38]
# i = 1, int1 = 24, int2 = 27 (fail order = True, fail diff = False)
# --------------------------------------------------
# [78, 75, 78, 79, 83, 80]
# i = 1, int1 = 75, int2 = 78 (fail order = True, fail diff = False)
# --------------------------------------------------
# [65, 64, 67, 68, 72, 72]
# i = 1, int1 = 64, int2 = 67 (fail order = True, fail diff = False)
# --------------------------------------------------
# [11, 9, 12, 15, 19, 20, 21, 25]
# i = 1, int1 = 9, int2 = 12 (fail order = True, fail diff = False)
# --------------------------------------------------
# [30, 29, 33, 34, 36, 37, 38, 43]
# i = 1, int1 = 29, int2 = 33 (fail order = True, fail diff = True)
# --------------------------------------------------
# [15, 12, 14, 16, 23, 26]
# i = 1, int1 = 12, int2 = 14 (fail order = True, fail diff = False)
# --------------------------------------------------
# [78, 77, 82, 85, 82]
# i = 1, int1 = 77, int2 = 82 (fail order = True, fail diff = True)
# --------------------------------------------------
# [59, 58, 65, 66, 66]
# i = 1, int1 = 58, int2 = 65 (fail order = True, fail diff = True)
# --------------------------------------------------
# [53, 52, 54, 56, 62, 64, 68]
# i = 1, int1 = 52, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [54, 51, 54, 56, 63, 64, 71]
# i = 1, int1 = 51, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [21, 21, 24, 27, 28, 31, 28]
# i = 0, int1 = 21, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 13, 16, 17, 18, 21, 21]
# i = 0, int1 = 13, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [5, 5, 7, 10, 13, 16, 17, 21]
# i = 0, int1 = 5, int2 = 5 (fail order = False, fail diff = True)
# --------------------------------------------------
# [3, 3, 4, 6, 12]
# i = 0, int1 = 3, int2 = 3 (fail order = False, fail diff = True)
# --------------------------------------------------
# [44, 44, 41, 42, 44, 45, 48, 51]
# i = 0, int1 = 44, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [76, 76, 73, 76, 79, 82, 80]
# i = 0, int1 = 76, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [81, 81, 83, 85, 84, 84]
# i = 0, int1 = 81, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 46, 43, 46, 50]
# i = 0, int1 = 46, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [81, 81, 83, 85, 88, 85, 88, 95]
# i = 0, int1 = 81, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 10, 10, 13, 14]
# i = 0, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [75, 75, 75, 77, 76]
# i = 0, int1 = 75, int2 = 75 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 43, 43, 45, 45]
# i = 0, int1 = 43, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [92, 92, 93, 93, 97]
# i = 0, int1 = 92, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 52, 53, 53, 59]
# i = 0, int1 = 52, int2 = 52 (fail order = False, fail diff = True)
# --------------------------------------------------
# [77, 77, 78, 82, 85]
# i = 0, int1 = 77, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 20, 24, 26, 28, 26]
# i = 0, int1 = 20, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [4, 4, 8, 9, 12, 12]
# i = 0, int1 = 4, int2 = 4 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 43, 46, 50, 54]
# i = 0, int1 = 43, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [45, 45, 46, 50, 51, 56]
# i = 0, int1 = 45, int2 = 45 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 67, 68, 69, 70, 77, 78, 80]
# i = 0, int1 = 67, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 57, 62, 65, 63]
# i = 0, int1 = 57, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [53, 53, 60, 63, 65, 65]
# i = 0, int1 = 53, int2 = 53 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 67, 73, 74, 76, 80]
# i = 0, int1 = 67, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [8, 8, 14, 16, 17, 19, 26]
# i = 0, int1 = 8, int2 = 8 (fail order = False, fail diff = True)
# --------------------------------------------------
# [84, 88, 91, 94, 97, 94]
# i = 0, int1 = 84, int2 = 88 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 23, 24, 26, 29, 30, 30]
# i = 0, int1 = 19, int2 = 23 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 61, 64, 66, 68, 69, 73]
# i = 0, int1 = 57, int2 = 61 (fail order = False, fail diff = True)
# --------------------------------------------------
# [28, 32, 33, 35, 42]
# i = 0, int1 = 28, int2 = 32 (fail order = False, fail diff = True)
# --------------------------------------------------
# [17, 21, 23, 26, 25, 26, 28]
# i = 0, int1 = 17, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [77, 81, 79, 80, 82, 83, 85, 83]
# i = 0, int1 = 77, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 91, 92, 89, 92, 92]
# i = 0, int1 = 87, int2 = 91 (fail order = False, fail diff = True)
# --------------------------------------------------
# [39, 43, 42, 43, 47]
# i = 0, int1 = 39, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [39, 43, 46, 44, 50]
# i = 0, int1 = 39, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 58, 59, 59, 61, 64]
# i = 0, int1 = 54, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [61, 65, 65, 66, 68, 65]
# i = 0, int1 = 61, int2 = 65 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 66, 68, 69, 70, 70, 70]
# i = 0, int1 = 62, int2 = 66 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 19, 19, 22, 24, 28]
# i = 0, int1 = 15, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 71, 73, 73, 74, 79]
# i = 0, int1 = 67, int2 = 71 (fail order = False, fail diff = True)
# --------------------------------------------------
# [75, 79, 83, 84, 86, 87, 89, 90]
# i = 0, int1 = 75, int2 = 79 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 17, 19, 20, 24, 26, 23]
# i = 0, int1 = 13, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [38, 42, 44, 47, 50, 54, 55, 55]
# i = 0, int1 = 38, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [22, 26, 30, 31, 33, 37]
# i = 0, int1 = 22, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 44, 47, 50, 52, 53, 57, 64]
# i = 0, int1 = 40, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [27, 31, 34, 41, 42]
# i = 0, int1 = 27, int2 = 31 (fail order = False, fail diff = True)
# --------------------------------------------------
# [44, 48, 50, 51, 56, 53]
# i = 0, int1 = 44, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 50, 51, 54, 55, 62, 63, 63]
# i = 0, int1 = 46, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 58, 61, 66, 67, 71]
# i = 0, int1 = 54, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [45, 49, 52, 54, 56, 62, 64, 70]
# i = 0, int1 = 45, int2 = 49 (fail order = False, fail diff = True)
# --------------------------------------------------
# [69, 74, 76, 79, 82, 79]
# i = 0, int1 = 69, int2 = 74 (fail order = False, fail diff = True)
# --------------------------------------------------
# [69, 75, 78, 81, 83, 85, 85]
# i = 0, int1 = 69, int2 = 75 (fail order = False, fail diff = True)
# --------------------------------------------------
# [45, 50, 51, 52, 55, 58, 62]
# i = 0, int1 = 45, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 36, 39, 41, 42, 49]
# i = 0, int1 = 29, int2 = 36 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 55, 54, 57, 59, 62, 65]
# i = 0, int1 = 50, int2 = 55 (fail order = False, fail diff = True)
# --------------------------------------------------
# [32, 37, 35, 38, 40, 42, 40]
# i = 0, int1 = 32, int2 = 37 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 57, 58, 57, 60, 61, 61]
# i = 0, int1 = 50, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 86, 89, 91, 89, 93]
# i = 0, int1 = 79, int2 = 86 (fail order = False, fail diff = True)
# --------------------------------------------------
# [30, 35, 33, 36, 41]
# i = 0, int1 = 30, int2 = 35 (fail order = False, fail diff = True)
# --------------------------------------------------
# [6, 13, 15, 16, 16, 18]
# i = 0, int1 = 6, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 25, 28, 31, 31, 32, 29]
# i = 0, int1 = 20, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 92, 93, 96, 96, 98, 98]
# i = 0, int1 = 87, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 20, 20, 23, 27]
# i = 0, int1 = 15, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [11, 17, 20, 23, 23, 28]
# i = 0, int1 = 11, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 59, 60, 64, 67]
# i = 0, int1 = 52, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [2, 8, 9, 10, 14, 15, 16, 13]
# i = 0, int1 = 2, int2 = 8 (fail order = False, fail diff = True)
# --------------------------------------------------
# [76, 81, 84, 85, 89, 91, 91]
# i = 0, int1 = 76, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 48, 51, 55, 57, 60, 63, 67]
# i = 0, int1 = 43, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [8, 14, 15, 17, 21, 27]
# i = 0, int1 = 8, int2 = 14 (fail order = False, fail diff = True)
# --------------------------------------------------
# [4, 9, 10, 16, 18, 19, 22, 25]
# i = 0, int1 = 4, int2 = 9 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 78, 84, 85, 87, 84]
# i = 0, int1 = 71, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [4, 11, 14, 20, 22, 22]
# i = 0, int1 = 4, int2 = 11 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 42, 47, 48, 49, 53]
# i = 0, int1 = 37, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [72, 79, 82, 87, 90, 97]
# i = 0, int1 = 72, int2 = 79 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 30, 29, 32, 35]
# i = 2, int1 = 29, int2 = 32 (fail order = True, fail diff = False)
# --------------------------------------------------
# [89, 88, 85, 83, 80, 79, 81, 81]
# i = 5, int1 = 79, int2 = 81 (fail order = True, fail diff = False)
# --------------------------------------------------
# [47, 46, 47, 46, 42]
# i = 1, int1 = 46, int2 = 47 (fail order = True, fail diff = False)
# --------------------------------------------------
# [59, 57, 55, 52, 49, 46, 48, 41]
# i = 5, int1 = 46, int2 = 48 (fail order = True, fail diff = False)
# --------------------------------------------------
# [71, 68, 68, 65, 64, 63, 61, 64]
# i = 1, int1 = 68, int2 = 68 (fail order = True, fail diff = True)
# --------------------------------------------------
# [92, 89, 86, 85, 84, 84, 84]
# i = 4, int1 = 84, int2 = 84 (fail order = True, fail diff = True)
# --------------------------------------------------
# [97, 96, 93, 93, 92, 91, 87]
# i = 2, int1 = 93, int2 = 93 (fail order = True, fail diff = True)
# --------------------------------------------------
# [76, 74, 71, 71, 70, 63]
# i = 2, int1 = 71, int2 = 71 (fail order = True, fail diff = True)
# --------------------------------------------------
# [38, 37, 33, 32, 29, 26, 25]
# i = 1, int1 = 37, int2 = 33 (fail order = False, fail diff = True)
# --------------------------------------------------
# [47, 46, 44, 40, 40]
# i = 2, int1 = 44, int2 = 40 (fail order = False, fail diff = True)
# --------------------------------------------------
# [99, 98, 94, 91, 88, 87, 84, 80]
# i = 1, int1 = 98, int2 = 94 (fail order = False, fail diff = True)
# --------------------------------------------------
# [86, 85, 82, 78, 77, 71]
# i = 2, int1 = 82, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 18, 17, 11, 10]
# i = 2, int1 = 17, int2 = 11 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 60, 58, 52, 53]
# i = 2, int1 = 58, int2 = 52 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 44, 37, 36, 35, 32, 32]
# i = 1, int1 = 44, int2 = 37 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 47, 45, 39, 35]
# i = 2, int1 = 45, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [74, 71, 70, 67, 60, 57, 51]
# i = 3, int1 = 67, int2 = 60 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 90, 89, 87, 85, 83]
# i = 1, int1 = 90, int2 = 89 (fail order = True, fail diff = False)
# --------------------------------------------------
# [28, 29, 28, 25, 24, 23, 21, 24]
# i = 1, int1 = 29, int2 = 28 (fail order = True, fail diff = False)
# --------------------------------------------------
# [44, 46, 44, 41, 38, 35, 35]
# i = 1, int1 = 46, int2 = 44 (fail order = True, fail diff = False)
# --------------------------------------------------
# [70, 71, 70, 67, 64, 63, 59]
# i = 1, int1 = 71, int2 = 70 (fail order = True, fail diff = False)
# --------------------------------------------------
# [49, 52, 49, 46, 40]
# i = 1, int1 = 52, int2 = 49 (fail order = True, fail diff = False)
# --------------------------------------------------
# [88, 89, 87, 88, 87, 85]
# i = 1, int1 = 89, int2 = 87 (fail order = True, fail diff = False)
# --------------------------------------------------
# [44, 47, 45, 42, 43, 41, 43]
# i = 1, int1 = 47, int2 = 45 (fail order = True, fail diff = False)
# --------------------------------------------------
# [3, 5, 8, 7, 6, 3, 3]
# i = 2, int1 = 8, int2 = 7 (fail order = True, fail diff = False)
# --------------------------------------------------
# [85, 88, 91, 88, 85, 81]
# i = 2, int1 = 91, int2 = 88 (fail order = True, fail diff = False)
# --------------------------------------------------
# [55, 58, 55, 54, 57, 54, 47]
# i = 1, int1 = 58, int2 = 55 (fail order = True, fail diff = False)
# --------------------------------------------------
# [16, 18, 16, 15, 15, 14, 13]
# i = 1, int1 = 18, int2 = 16 (fail order = True, fail diff = False)
# --------------------------------------------------
# [75, 77, 75, 75, 78]
# i = 1, int1 = 77, int2 = 75 (fail order = True, fail diff = False)
# --------------------------------------------------
# [43, 46, 43, 40, 38, 38, 36, 36]
# i = 1, int1 = 46, int2 = 43 (fail order = True, fail diff = False)
# --------------------------------------------------
# [94, 95, 94, 91, 88, 88, 87, 83]
# i = 1, int1 = 95, int2 = 94 (fail order = True, fail diff = False)
# --------------------------------------------------
# [68, 70, 69, 67, 64, 64, 58]
# i = 1, int1 = 70, int2 = 69 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 53, 49, 47, 48]
# i = 1, int1 = 53, int2 = 49 (fail order = True, fail diff = True)
# --------------------------------------------------
# [43, 45, 42, 40, 38, 34, 32, 32]
# i = 1, int1 = 45, int2 = 42 (fail order = True, fail diff = False)
# --------------------------------------------------
# [43, 44, 43, 41, 39, 35, 32, 28]
# i = 1, int1 = 44, int2 = 43 (fail order = True, fail diff = False)
# --------------------------------------------------
# [55, 57, 53, 51, 44]
# i = 1, int1 = 57, int2 = 53 (fail order = True, fail diff = True)
# --------------------------------------------------
# [43, 45, 44, 37, 36, 34]
# i = 1, int1 = 45, int2 = 44 (fail order = True, fail diff = False)
# --------------------------------------------------
# [88, 90, 88, 85, 78, 76, 79]
# i = 1, int1 = 90, int2 = 88 (fail order = True, fail diff = False)
# --------------------------------------------------
# [57, 60, 57, 52, 50, 50]
# i = 1, int1 = 60, int2 = 57 (fail order = True, fail diff = False)
# --------------------------------------------------
# [43, 46, 40, 39, 38, 37, 36, 32]
# i = 1, int1 = 46, int2 = 40 (fail order = True, fail diff = True)
# --------------------------------------------------
# [95, 96, 89, 88, 81]
# i = 1, int1 = 96, int2 = 89 (fail order = True, fail diff = True)
# --------------------------------------------------
# [73, 73, 72, 71, 69, 68, 71]
# i = 0, int1 = 73, int2 = 73 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 43, 42, 41, 38, 38]
# i = 0, int1 = 43, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 23, 20, 17, 13]
# i = 0, int1 = 23, int2 = 23 (fail order = False, fail diff = True)
# --------------------------------------------------
# [42, 42, 40, 37, 35, 28]
# i = 0, int1 = 42, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 10, 8, 6, 9, 8]
# i = 0, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 40, 39, 41, 42]
# i = 0, int1 = 40, int2 = 40 (fail order = False, fail diff = True)
# --------------------------------------------------
# [6, 6, 4, 6, 5, 5]
# i = 0, int1 = 6, int2 = 6 (fail order = False, fail diff = True)
# --------------------------------------------------
# [31, 31, 30, 32, 30, 26]
# i = 0, int1 = 31, int2 = 31 (fail order = False, fail diff = True)
# --------------------------------------------------
# [35, 35, 34, 32, 34, 33, 32, 25]
# i = 0, int1 = 35, int2 = 35 (fail order = False, fail diff = True)
# --------------------------------------------------
# [27, 27, 25, 24, 24, 23, 21]
# i = 0, int1 = 27, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 54, 52, 49, 49, 48, 45, 47]
# i = 0, int1 = 54, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [56, 56, 56, 55, 55]
# i = 0, int1 = 56, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [51, 51, 48, 48, 47, 43]
# i = 0, int1 = 51, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 19, 19, 17, 11]
# i = 0, int1 = 19, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 54, 52, 49, 46, 42, 41]
# i = 0, int1 = 54, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [65, 65, 64, 60, 61]
# i = 0, int1 = 65, int2 = 65 (fail order = False, fail diff = True)
# --------------------------------------------------
# [24, 24, 23, 19, 16, 13, 13]
# i = 0, int1 = 24, int2 = 24 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 64, 60, 57, 53]
# i = 0, int1 = 64, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [88, 88, 87, 86, 83, 79, 73]
# i = 0, int1 = 88, int2 = 88 (fail order = False, fail diff = True)
# --------------------------------------------------
# [48, 48, 42, 39, 37, 36, 33]
# i = 0, int1 = 48, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [76, 76, 71, 70, 69, 68, 69]
# i = 0, int1 = 76, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [26, 26, 24, 19, 19]
# i = 0, int1 = 26, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 21, 18, 16, 11, 9, 5]
# i = 0, int1 = 21, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 46, 45, 43, 41, 40, 33, 26]
# i = 0, int1 = 46, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [60, 56, 55, 52, 51, 49, 51]
# i = 0, int1 = 60, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 50, 49, 47, 46, 46]
# i = 0, int1 = 54, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [42, 38, 35, 34, 32, 29, 25]
# i = 0, int1 = 42, int2 = 38 (fail order = False, fail diff = True)
# --------------------------------------------------
# [94, 90, 87, 86, 83, 81, 74]
# i = 0, int1 = 94, int2 = 90 (fail order = False, fail diff = True)
# --------------------------------------------------
# [58, 54, 53, 50, 49, 52, 50]
# i = 0, int1 = 58, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 48, 46, 44, 46, 49]
# i = 0, int1 = 52, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 25, 23, 21, 18, 17, 20, 20]
# i = 0, int1 = 29, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 19, 18, 21, 19, 17, 13]
# i = 0, int1 = 23, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 33, 32, 34, 28]
# i = 0, int1 = 37, int2 = 33 (fail order = False, fail diff = True)
# --------------------------------------------------
# [82, 78, 75, 75, 73, 71, 68, 65]
# i = 0, int1 = 82, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [31, 27, 25, 23, 22, 19, 19, 22]
# i = 0, int1 = 31, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 51, 48, 48, 48]
# i = 0, int1 = 55, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [38, 34, 32, 29, 27, 27, 26, 22]
# i = 0, int1 = 38, int2 = 34 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 51, 50, 48, 48, 47, 42]
# i = 0, int1 = 55, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [81, 77, 75, 71, 70]
# i = 0, int1 = 81, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 39, 37, 33, 31, 34]
# i = 0, int1 = 43, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 51, 50, 49, 48, 47, 43, 43]
# i = 0, int1 = 55, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 15, 11, 9, 6, 2]
# i = 0, int1 = 19, int2 = 15 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 67, 66, 62, 61, 58, 52]
# i = 0, int1 = 71, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [41, 37, 36, 35, 30, 29, 26, 23]
# i = 0, int1 = 41, int2 = 37 (fail order = False, fail diff = True)
# --------------------------------------------------
# [53, 49, 43, 40, 37, 39]
# i = 0, int1 = 53, int2 = 49 (fail order = False, fail diff = True)
# --------------------------------------------------
# [88, 84, 82, 79, 74, 72, 70, 70]
# i = 0, int1 = 88, int2 = 84 (fail order = False, fail diff = True)
# --------------------------------------------------
# [97, 93, 87, 85, 81]
# i = 0, int1 = 97, int2 = 93 (fail order = False, fail diff = True)
# --------------------------------------------------
# [96, 92, 91, 84, 83, 78]
# i = 0, int1 = 96, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [98, 91, 90, 87, 85, 83, 84]
# i = 0, int1 = 98, int2 = 91 (fail order = False, fail diff = True)
# --------------------------------------------------
# [31, 24, 23, 21, 18, 17, 17]
# i = 0, int1 = 31, int2 = 24 (fail order = False, fail diff = True)
# --------------------------------------------------
# [70, 64, 63, 61, 57]
# i = 0, int1 = 70, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [61, 54, 52, 49, 46, 43, 37]
# i = 0, int1 = 61, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 17, 15, 13, 12, 11, 14, 13]
# i = 0, int1 = 23, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [49, 42, 39, 41, 39, 38, 40]
# i = 0, int1 = 49, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 26, 29, 27, 26, 26]
# i = 0, int1 = 33, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 31, 32, 30, 28, 25, 21]
# i = 0, int1 = 37, int2 = 31 (fail order = False, fail diff = True)
# --------------------------------------------------
# [70, 63, 60, 63, 60, 57, 56, 50]
# i = 0, int1 = 70, int2 = 63 (fail order = False, fail diff = True)
# --------------------------------------------------
# [56, 50, 48, 47, 44, 41, 41, 39]
# i = 0, int1 = 56, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [39, 34, 34, 33, 30, 28, 27, 29]
# i = 0, int1 = 39, int2 = 34 (fail order = False, fail diff = True)
# --------------------------------------------------
# [63, 56, 54, 54, 54]
# i = 0, int1 = 63, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [86, 80, 80, 77, 75, 74, 71, 67]
# i = 0, int1 = 86, int2 = 80 (fail order = False, fail diff = True)
# --------------------------------------------------
# [24, 18, 15, 14, 12, 11, 11, 6]
# i = 0, int1 = 24, int2 = 18 (fail order = False, fail diff = True)
# --------------------------------------------------
# [69, 64, 62, 60, 56, 55]
# i = 0, int1 = 69, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [82, 76, 72, 71, 69, 66, 63, 65]
# i = 0, int1 = 82, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [85, 78, 74, 72, 72]
# i = 0, int1 = 85, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [78, 72, 68, 67, 63]
# i = 0, int1 = 78, int2 = 72 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 74, 72, 70, 68, 64, 59]
# i = 0, int1 = 79, int2 = 74 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 47, 41, 40, 39, 36, 34, 31]
# i = 0, int1 = 52, int2 = 47 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 41, 40, 34, 31, 28, 31]
# i = 0, int1 = 46, int2 = 41 (fail order = False, fail diff = True)
# --------------------------------------------------
# [26, 19, 16, 14, 9, 9]
# i = 0, int1 = 26, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [72, 67, 62, 60, 56]
# i = 0, int1 = 72, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [85, 78, 72, 69, 68, 63]
# i = 0, int1 = 85, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [83, 80, 77, 77, 74, 74]
# i = 2, int1 = 77, int2 = 77 (fail order = True, fail diff = True)
# --------------------------------------------------
# [54, 50, 48, 45, 41, 38, 34]
# i = 0, int1 = 54, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [60, 57, 59, 62, 60]
# i = 1, int1 = 57, int2 = 59 (fail order = True, fail diff = False)
# --------------------------------------------------
# [41, 38, 40, 47, 50, 52, 56]
# i = 1, int1 = 38, int2 = 40 (fail order = True, fail diff = False)
# --------------------------------------------------
# [74, 72, 73, 71, 74, 75, 77, 77]
# i = 1, int1 = 72, int2 = 73 (fail order = True, fail diff = False)
# --------------------------------------------------
# [67, 65, 63, 61, 60, 56, 55, 48]
# i = 4, int1 = 60, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [5, 9, 10, 11, 8, 10, 14]
# i = 0, int1 = 5, int2 = 9 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 70, 73, 74, 71, 75]
# i = 1, int1 = 70, int2 = 73 (fail order = True, fail diff = False)
# --------------------------------------------------
# [56, 56, 53, 55, 56, 60]
# i = 0, int1 = 56, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [74, 77, 78, 80, 81, 84, 84, 83]
# i = 5, int1 = 84, int2 = 84 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 62, 59, 57, 53]
# i = 0, int1 = 62, int2 = 62 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 85, 85, 88, 90, 94]
# i = 0, int1 = 79, int2 = 85 (fail order = False, fail diff = True)
# --------------------------------------------------
# [32, 30, 31, 33, 33, 34, 35, 35]
# i = 1, int1 = 30, int2 = 31 (fail order = True, fail diff = False)
# --------------------------------------------------
# [3, 7, 6, 9, 10, 12, 14, 14]
# i = 0, int1 = 3, int2 = 7 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 39, 36, 33, 33]
# i = 1, int1 = 39, int2 = 36 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 52, 47, 46, 45, 44, 44]
# i = 1, int1 = 52, int2 = 47 (fail order = True, fail diff = True)
# --------------------------------------------------
# [56, 52, 50, 49, 49, 47, 45, 46]
# i = 0, int1 = 56, int2 = 52 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 58, 61, 62, 64, 68]
# i = 0, int1 = 52, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [49, 49, 50, 52, 53, 55, 58, 58]
# i = 0, int1 = 49, int2 = 49 (fail order = False, fail diff = True)
# --------------------------------------------------
# [35, 32, 33, 37, 38, 37]
# i = 1, int1 = 32, int2 = 33 (fail order = True, fail diff = False)
# --------------------------------------------------
# [48, 45, 47, 49, 48, 50, 51]
# i = 1, int1 = 45, int2 = 47 (fail order = True, fail diff = False)
# --------------------------------------------------
# [8, 10, 10, 11, 11]
# i = 1, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 37, 38, 44, 50]
# i = 1, int1 = 37, int2 = 38 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 58, 60, 63, 60, 67]
# i = 0, int1 = 51, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 34, 37, 44, 46, 48, 51, 55]
# i = 2, int1 = 37, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [66, 69, 70, 73, 76, 79, 77, 83]
# i = 5, int1 = 79, int2 = 77 (fail order = True, fail diff = False)
# --------------------------------------------------
# [72, 72, 71, 70, 63, 62, 58]
# i = 0, int1 = 72, int2 = 72 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 62, 61, 60, 59, 56, 58, 51]
# i = 5, int1 = 56, int2 = 58 (fail order = True, fail diff = False)
# --------------------------------------------------
# [4, 1, 4, 5, 6, 9, 10]
# i = 1, int1 = 1, int2 = 4 (fail order = True, fail diff = False)
# --------------------------------------------------
# [76, 70, 68, 64, 67]
# i = 0, int1 = 76, int2 = 70 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 44, 45, 48, 52, 54]
# i = 0, int1 = 40, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [61, 68, 70, 77, 79, 81, 81]
# i = 0, int1 = 61, int2 = 68 (fail order = False, fail diff = True)
# --------------------------------------------------
# [14, 12, 12, 14, 17, 19, 20, 21]
# i = 1, int1 = 12, int2 = 12 (fail order = True, fail diff = True)
# --------------------------------------------------
# [29, 33, 35, 36, 40]
# i = 0, int1 = 29, int2 = 33 (fail order = False, fail diff = True)
# --------------------------------------------------
# [90, 90, 88, 88, 86, 85, 84, 87]
# i = 0, int1 = 90, int2 = 90 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 24, 27, 30, 37, 41]
# i = 0, int1 = 19, int2 = 24 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 63, 61, 57, 56, 55, 52, 53]
# i = 2, int1 = 61, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [75, 75, 72, 70, 64, 61, 64]
# i = 0, int1 = 75, int2 = 75 (fail order = False, fail diff = True)
# --------------------------------------------------
# [66, 69, 73, 74, 78]
# i = 1, int1 = 69, int2 = 73 (fail order = False, fail diff = True)
# --------------------------------------------------
# [56, 57, 54, 51, 51, 49, 45]
# i = 1, int1 = 57, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [56, 56, 57, 63, 66]
# i = 0, int1 = 56, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 13, 16, 19, 21, 22, 22]
# i = 0, int1 = 9, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [65, 62, 63, 68, 68]
# i = 1, int1 = 62, int2 = 63 (fail order = True, fail diff = False)
# --------------------------------------------------
# [74, 72, 73, 80, 82, 84, 87, 89]
# i = 1, int1 = 72, int2 = 73 (fail order = True, fail diff = False)
# --------------------------------------------------
# [67, 62, 60, 58, 57, 59, 55]
# i = 0, int1 = 67, int2 = 62 (fail order = False, fail diff = True)
# --------------------------------------------------
# [60, 63, 61, 57, 52]
# i = 1, int1 = 63, int2 = 61 (fail order = True, fail diff = False)
# --------------------------------------------------
# [63, 67, 70, 77, 77]
# i = 0, int1 = 63, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 68, 69, 68, 67, 64, 61, 62]
# i = 1, int1 = 68, int2 = 69 (fail order = True, fail diff = False)
# --------------------------------------------------
# [55, 59, 60, 60, 62, 60]
# i = 0, int1 = 55, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 59, 56, 54, 53, 53, 53]
# i = 0, int1 = 59, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [25, 25, 23, 25, 23, 20, 23]
# i = 0, int1 = 25, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 53, 52, 50, 50, 49, 47]
# i = 0, int1 = 59, int2 = 53 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 57, 59, 61, 63, 65, 70]
# i = 0, int1 = 57, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [16, 16, 17, 18, 21, 21, 22, 22]
# i = 0, int1 = 16, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [36, 30, 29, 32, 33]
# i = 0, int1 = 36, int2 = 30 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 51, 49, 42, 40, 40]
# i = 2, int1 = 49, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [34, 36, 39, 41, 42, 40, 40]
# i = 4, int1 = 42, int2 = 40 (fail order = True, fail diff = False)
# --------------------------------------------------
# [97, 90, 89, 87, 84, 82, 79, 79]
# i = 0, int1 = 97, int2 = 90 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 11, 9, 7, 4, 4]
# i = 0, int1 = 15, int2 = 11 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 25, 27, 24, 27, 30, 27]
# i = 0, int1 = 21, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 30, 29, 28, 27, 30, 23]
# i = 1, int1 = 30, int2 = 29 (fail order = True, fail diff = False)
# --------------------------------------------------
# [18, 22, 26, 27, 30, 34]
# i = 0, int1 = 18, int2 = 22 (fail order = False, fail diff = True)
# --------------------------------------------------
# [35, 39, 42, 44, 45, 48, 52, 58]
# i = 0, int1 = 35, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 30, 32, 33, 35, 36, 41, 42]
# i = 5, int1 = 36, int2 = 41 (fail order = False, fail diff = True)
# --------------------------------------------------
# [91, 87, 84, 82, 75, 74, 71, 70]
# i = 0, int1 = 91, int2 = 87 (fail order = False, fail diff = True)
# --------------------------------------------------
# [93, 93, 91, 93, 91, 90, 90]
# i = 0, int1 = 93, int2 = 93 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 64, 61, 60, 58, 53, 53]
# i = 0, int1 = 64, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [41, 44, 42, 44, 43, 42, 38]
# i = 1, int1 = 44, int2 = 42 (fail order = True, fail diff = False)
# --------------------------------------------------
# [56, 57, 55, 51, 49, 45]
# i = 1, int1 = 57, int2 = 55 (fail order = True, fail diff = False)
# --------------------------------------------------
# [67, 73, 76, 78, 79, 78]
# i = 0, int1 = 67, int2 = 73 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 79, 81, 83, 87, 88, 88]
# i = 0, int1 = 79, int2 = 79 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 60, 57, 56, 54, 49]
# i = 1, int1 = 60, int2 = 57 (fail order = True, fail diff = False)
# --------------------------------------------------
# [34, 34, 35, 36, 38, 36, 38, 39]
# i = 0, int1 = 34, int2 = 34 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 63, 60, 54, 50]
# i = 2, int1 = 60, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [88, 89, 86, 86, 89]
# i = 1, int1 = 89, int2 = 86 (fail order = True, fail diff = False)
# --------------------------------------------------
# [17, 16, 19, 23, 24, 27, 31]
# i = 1, int1 = 16, int2 = 19 (fail order = True, fail diff = False)
# --------------------------------------------------
# [91, 87, 86, 83, 80, 77, 73]
# i = 0, int1 = 91, int2 = 87 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 21, 23, 24, 26, 29, 34]
# i = 1, int1 = 21, int2 = 23 (fail order = True, fail diff = False)
# --------------------------------------------------
# [53, 51, 48, 47, 45, 43, 39, 36]
# i = 5, int1 = 43, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 20, 22, 26, 29, 30, 33, 31]
# i = 0, int1 = 13, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [91, 90, 87, 85, 81, 81]
# i = 3, int1 = 85, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 16, 15, 12, 11, 11, 8, 8]
# i = 1, int1 = 16, int2 = 15 (fail order = True, fail diff = False)
# --------------------------------------------------
# [79, 74, 71, 68, 67, 66, 62]
# i = 0, int1 = 79, int2 = 74 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 59, 58, 51, 45]
# i = 0, int1 = 59, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [38, 40, 45, 48, 51, 51]
# i = 1, int1 = 40, int2 = 45 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 56, 54, 51, 49, 49, 48, 42]
# i = 1, int1 = 56, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [32, 26, 25, 20, 19, 19]
# i = 0, int1 = 32, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [36, 43, 46, 48, 48, 49]
# i = 0, int1 = 36, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 7, 7, 9, 12, 17]
# i = 1, int1 = 7, int2 = 7 (fail order = True, fail diff = True)
# --------------------------------------------------
# [17, 21, 24, 27, 32, 33, 35, 36]
# i = 0, int1 = 17, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [51, 46, 44, 41, 39, 38, 34, 34]
# i = 0, int1 = 51, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [96, 96, 93, 90, 88, 85, 81, 83]
# i = 0, int1 = 96, int2 = 96 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 27, 30, 32, 33, 36, 41, 38]
# i = 0, int1 = 21, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 48, 45, 42, 41, 38, 34]
# i = 1, int1 = 48, int2 = 45 (fail order = True, fail diff = False)
# --------------------------------------------------
# [87, 84, 86, 84, 87, 90, 96]
# i = 1, int1 = 84, int2 = 86 (fail order = True, fail diff = False)
# --------------------------------------------------
# [80, 80, 81, 85, 90]
# i = 0, int1 = 80, int2 = 80 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 38, 41, 40, 42, 44, 45, 44]
# i = 0, int1 = 33, int2 = 38 (fail order = False, fail diff = True)
# --------------------------------------------------
# [66, 60, 58, 54, 53]
# i = 0, int1 = 66, int2 = 60 (fail order = False, fail diff = True)
# --------------------------------------------------
# [26, 19, 16, 14, 10, 4]
# i = 0, int1 = 26, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 44, 47, 47, 49, 52, 56]
# i = 0, int1 = 40, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 76, 77, 78, 79, 79]
# i = 0, int1 = 71, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [92, 92, 91, 92, 95, 93]
# i = 0, int1 = 92, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 70, 68, 63, 61, 60, 61]
# i = 2, int1 = 68, int2 = 63 (fail order = False, fail diff = True)
# --------------------------------------------------
# [32, 32, 34, 39, 39]
# i = 0, int1 = 32, int2 = 32 (fail order = False, fail diff = True)
# --------------------------------------------------
# [68, 71, 69, 67, 66, 61, 55]
# i = 1, int1 = 71, int2 = 69 (fail order = True, fail diff = False)
# --------------------------------------------------
# [57, 61, 68, 69, 71, 75]
# i = 0, int1 = 57, int2 = 61 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 77, 79, 82, 84, 85, 87, 85]
# i = 0, int1 = 73, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [7, 9, 10, 11, 14, 13, 16, 14]
# i = 4, int1 = 14, int2 = 13 (fail order = True, fail diff = False)
# --------------------------------------------------
# [15, 10, 12, 9, 8, 1]
# i = 0, int1 = 15, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 63, 61, 54, 52]
# i = 1, int1 = 63, int2 = 61 (fail order = True, fail diff = False)
# --------------------------------------------------
# [31, 35, 36, 38, 39, 38, 39]
# i = 0, int1 = 31, int2 = 35 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 58, 60, 61, 62, 67, 65]
# i = 1, int1 = 58, int2 = 60 (fail order = True, fail diff = False)
# --------------------------------------------------
# [80, 76, 75, 74, 73, 71, 66, 68]
# i = 0, int1 = 80, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 64, 67, 71, 73, 80]
# i = 0, int1 = 59, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 46, 43, 43, 39]
# i = 0, int1 = 52, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 62, 59, 55, 51]
# i = 0, int1 = 67, int2 = 62 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 59, 62, 62, 65, 67, 68, 68]
# i = 0, int1 = 55, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [92, 92, 89, 86, 85, 84, 83, 78]
# i = 0, int1 = 92, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 44, 46, 46, 47, 44]
# i = 0, int1 = 37, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 17, 13, 11, 11]
# i = 0, int1 = 21, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [11, 15, 16, 17, 20, 21, 24, 31]
# i = 0, int1 = 11, int2 = 15 (fail order = False, fail diff = True)
# --------------------------------------------------
# [95, 91, 89, 86, 89]
# i = 0, int1 = 95, int2 = 91 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 50, 47, 44, 42, 45]
# i = 0, int1 = 50, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 16, 13, 13, 10, 7, 5, 5]
# i = 0, int1 = 20, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 20, 21, 22, 28]
# i = 0, int1 = 13, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 53, 51, 47, 46, 45, 48]
# i = 0, int1 = 57, int2 = 53 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 10, 8, 6, 4, 1, 3, 2]
# i = 0, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 68, 71, 73, 74, 80, 86]
# i = 0, int1 = 64, int2 = 68 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 16, 18, 16, 19, 19]
# i = 0, int1 = 10, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 90, 86, 84, 84]
# i = 1, int1 = 90, int2 = 86 (fail order = True, fail diff = True)
# --------------------------------------------------
# [29, 22, 20, 21, 19, 16]
# i = 0, int1 = 29, int2 = 22 (fail order = False, fail diff = True)
# --------------------------------------------------
# [2, 3, 5, 9, 15]
# i = 2, int1 = 5, int2 = 9 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 70, 67, 66, 63, 63, 62]
# i = 1, int1 = 70, int2 = 67 (fail order = True, fail diff = False)
# --------------------------------------------------
# [66, 63, 67, 70, 72, 74, 75, 75]
# i = 1, int1 = 63, int2 = 67 (fail order = True, fail diff = True)
# --------------------------------------------------
# [98, 98, 96, 95, 94, 94]
# i = 0, int1 = 98, int2 = 98 (fail order = False, fail diff = True)
# --------------------------------------------------
# [41, 41, 37, 34, 33, 31, 31]
# i = 0, int1 = 41, int2 = 41 (fail order = False, fail diff = True)
# --------------------------------------------------
# [84, 84, 85, 89, 90, 91, 93, 97]
# i = 0, int1 = 84, int2 = 84 (fail order = False, fail diff = True)
# --------------------------------------------------
# [17, 17, 13, 12, 7]
# i = 0, int1 = 17, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 13, 10, 7, 7, 5, 5]
# i = 0, int1 = 20, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [94, 96, 94, 93, 92, 89, 91]
# i = 1, int1 = 96, int2 = 94 (fail order = True, fail diff = False)
# --------------------------------------------------
# [38, 38, 41, 43, 47, 49, 51]
# i = 0, int1 = 38, int2 = 38 (fail order = False, fail diff = True)
# --------------------------------------------------
# 631

# %% [markdown]
# !! What could be making it unsafe is the one BEFORE the left one, because of the order. Example:

# %%
line = "3 1 2 4 5"
report = line_to_list(line)
is_report_safe_tolerate(report)
# Out:
# [3, 1, 2, 4, 5]
# i = 1, int1 = 1, int2 = 2 (fail order = True, fail diff = False)
# --------------------------------------------------
# False

# %% [markdown]
# This one is actually safe, if we remove the one at i = 0

# %%
def is_report_safe_tolerate(report: list[int], strict: bool = False, debug: bool = DEBUG) -> bool:

    safe = True
    order = ints_order(report[0],report[1])
    i = 0
    
    while i < (len(report) - 1):
        int1 = report[i]
        int2 = report[i+1]
        diff = abs(int1 - int2) 
         
        fail1 = ints_order(int1, int2) != order
        fail2 = diff < 1 or diff > 3 
        if fail1 or fail2:
            if strict:
                safe = False
                break
            to_check_strictly = [remove_element(report, i), remove_element(report, i+1)]
            if i > 0:
                to_check_strictly.append(remove_element(report, i-1))
            remove_is_safe = any([is_report_safe_tolerate(r, strict=True, debug=False) for r in to_check_strictly])
            if remove_is_safe: 
                safe = True
                break
            else:
                safe = False 
                break    
        i += 1
    
    if not safe and debug:
        print(report)
        print(f'i = {i}, int1 = {int1}, int2 = {int2} (fail order = {fail1}, fail diff = {fail2})')
        print('-'*50)

    return safe

# %%
dat = samp 
sol_2024_2_2(dat)
# Out:
# [1, 2, 7, 8, 9]
# i = 1, int1 = 2, int2 = 7 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 7, 6, 2, 1]
# i = 2, int1 = 6, int2 = 2 (fail order = False, fail diff = True)
# --------------------------------------------------
# 4

# %%
dat = data 
sol_2024_2_2(dat)
# Out:
# [95, 97, 98, 99, 98, 99]
# i = 3, int1 = 99, int2 = 98 (fail order = True, fail diff = False)
# --------------------------------------------------
# [84, 85, 88, 89, 88, 85]
# i = 3, int1 = 89, int2 = 88 (fail order = True, fail diff = False)
# --------------------------------------------------
# [20, 23, 21, 24, 25, 28, 31, 31]
# i = 1, int1 = 23, int2 = 21 (fail order = True, fail diff = False)
# --------------------------------------------------
# [15, 16, 18, 17, 18, 22]
# i = 2, int1 = 18, int2 = 17 (fail order = True, fail diff = False)
# --------------------------------------------------
# [31, 32, 30, 32, 34, 39]
# i = 1, int1 = 32, int2 = 30 (fail order = True, fail diff = False)
# --------------------------------------------------
# [2, 4, 4, 5, 8, 9, 6]
# i = 1, int1 = 4, int2 = 4 (fail order = False, fail diff = True)
# --------------------------------------------------
# [68, 69, 72, 72, 72]
# i = 2, int1 = 72, int2 = 72 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 74, 77, 77, 80, 82, 83, 87]
# i = 2, int1 = 77, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [11, 13, 15, 16, 16, 17, 23]
# i = 3, int1 = 16, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 74, 78, 81, 84]
# i = 1, int1 = 74, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [51, 52, 54, 58, 59, 56]
# i = 2, int1 = 54, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 42, 46, 48, 51, 53, 53]
# i = 1, int1 = 42, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [18, 19, 20, 21, 25, 29]
# i = 3, int1 = 21, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 22, 23, 27, 28, 31, 38]
# i = 2, int1 = 23, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [3, 5, 8, 9, 14, 15]
# i = 3, int1 = 9, int2 = 14 (fail order = False, fail diff = True)
# --------------------------------------------------
# [1, 4, 5, 6, 13, 12]
# i = 3, int1 = 6, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 51, 57, 59, 60, 60]
# i = 1, int1 = 51, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [42, 45, 48, 54, 57, 61]
# i = 2, int1 = 48, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [17, 20, 23, 24, 29, 31, 37]
# i = 3, int1 = 24, int2 = 29 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 7, 8, 10, 13, 16, 15]
# i = 1, int1 = 7, int2 = 8 (fail order = True, fail diff = False)
# --------------------------------------------------
# [16, 14, 17, 18, 18]
# i = 1, int1 = 14, int2 = 17 (fail order = True, fail diff = False)
# --------------------------------------------------
# [49, 47, 50, 53, 55, 59]
# i = 1, int1 = 47, int2 = 50 (fail order = True, fail diff = False)
# --------------------------------------------------
# [21, 20, 23, 26, 27, 30, 35]
# i = 1, int1 = 20, int2 = 23 (fail order = True, fail diff = False)
# --------------------------------------------------
# [78, 77, 78, 81, 84, 82, 85, 86]
# i = 1, int1 = 77, int2 = 78 (fail order = True, fail diff = False)
# --------------------------------------------------
# [94, 91, 94, 93, 96, 93]
# i = 1, int1 = 91, int2 = 94 (fail order = True, fail diff = False)
# --------------------------------------------------
# [13, 12, 14, 12, 13, 13]
# i = 1, int1 = 12, int2 = 14 (fail order = True, fail diff = False)
# --------------------------------------------------
# [19, 17, 18, 20, 19, 23]
# i = 1, int1 = 17, int2 = 18 (fail order = True, fail diff = False)
# --------------------------------------------------
# [57, 54, 57, 55, 57, 64]
# i = 1, int1 = 54, int2 = 57 (fail order = True, fail diff = False)
# --------------------------------------------------
# [86, 84, 84, 85, 88]
# i = 1, int1 = 84, int2 = 84 (fail order = True, fail diff = True)
# --------------------------------------------------
# [16, 14, 14, 16, 15]
# i = 1, int1 = 14, int2 = 14 (fail order = True, fail diff = True)
# --------------------------------------------------
# [74, 72, 74, 74, 77, 79, 80, 80]
# i = 1, int1 = 72, int2 = 74 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 48, 49, 49, 53]
# i = 1, int1 = 48, int2 = 49 (fail order = True, fail diff = False)
# --------------------------------------------------
# [26, 24, 27, 29, 30, 33, 33, 38]
# i = 1, int1 = 24, int2 = 27 (fail order = True, fail diff = False)
# --------------------------------------------------
# [78, 75, 78, 79, 83, 80]
# i = 1, int1 = 75, int2 = 78 (fail order = True, fail diff = False)
# --------------------------------------------------
# [65, 64, 67, 68, 72, 72]
# i = 1, int1 = 64, int2 = 67 (fail order = True, fail diff = False)
# --------------------------------------------------
# [11, 9, 12, 15, 19, 20, 21, 25]
# i = 1, int1 = 9, int2 = 12 (fail order = True, fail diff = False)
# --------------------------------------------------
# [30, 29, 33, 34, 36, 37, 38, 43]
# i = 1, int1 = 29, int2 = 33 (fail order = True, fail diff = True)
# --------------------------------------------------
# [15, 12, 14, 16, 23, 26]
# i = 1, int1 = 12, int2 = 14 (fail order = True, fail diff = False)
# --------------------------------------------------
# [78, 77, 82, 85, 82]
# i = 1, int1 = 77, int2 = 82 (fail order = True, fail diff = True)
# --------------------------------------------------
# [59, 58, 65, 66, 66]
# i = 1, int1 = 58, int2 = 65 (fail order = True, fail diff = True)
# --------------------------------------------------
# [53, 52, 54, 56, 62, 64, 68]
# i = 1, int1 = 52, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [54, 51, 54, 56, 63, 64, 71]
# i = 1, int1 = 51, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [21, 21, 24, 27, 28, 31, 28]
# i = 0, int1 = 21, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 13, 16, 17, 18, 21, 21]
# i = 0, int1 = 13, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [5, 5, 7, 10, 13, 16, 17, 21]
# i = 0, int1 = 5, int2 = 5 (fail order = False, fail diff = True)
# --------------------------------------------------
# [3, 3, 4, 6, 12]
# i = 0, int1 = 3, int2 = 3 (fail order = False, fail diff = True)
# --------------------------------------------------
# [44, 44, 41, 42, 44, 45, 48, 51]
# i = 0, int1 = 44, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [76, 76, 73, 76, 79, 82, 80]
# i = 0, int1 = 76, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [81, 81, 83, 85, 84, 84]
# i = 0, int1 = 81, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 46, 43, 46, 50]
# i = 0, int1 = 46, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [81, 81, 83, 85, 88, 85, 88, 95]
# i = 0, int1 = 81, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 10, 10, 13, 14]
# i = 0, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [75, 75, 75, 77, 76]
# i = 0, int1 = 75, int2 = 75 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 43, 43, 45, 45]
# i = 0, int1 = 43, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [92, 92, 93, 93, 97]
# i = 0, int1 = 92, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 52, 53, 53, 59]
# i = 0, int1 = 52, int2 = 52 (fail order = False, fail diff = True)
# --------------------------------------------------
# [77, 77, 78, 82, 85]
# i = 0, int1 = 77, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 20, 24, 26, 28, 26]
# i = 0, int1 = 20, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [4, 4, 8, 9, 12, 12]
# i = 0, int1 = 4, int2 = 4 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 43, 46, 50, 54]
# i = 0, int1 = 43, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [45, 45, 46, 50, 51, 56]
# i = 0, int1 = 45, int2 = 45 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 67, 68, 69, 70, 77, 78, 80]
# i = 0, int1 = 67, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 57, 62, 65, 63]
# i = 0, int1 = 57, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [53, 53, 60, 63, 65, 65]
# i = 0, int1 = 53, int2 = 53 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 67, 73, 74, 76, 80]
# i = 0, int1 = 67, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [8, 8, 14, 16, 17, 19, 26]
# i = 0, int1 = 8, int2 = 8 (fail order = False, fail diff = True)
# --------------------------------------------------
# [84, 88, 91, 94, 97, 94]
# i = 0, int1 = 84, int2 = 88 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 23, 24, 26, 29, 30, 30]
# i = 0, int1 = 19, int2 = 23 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 61, 64, 66, 68, 69, 73]
# i = 0, int1 = 57, int2 = 61 (fail order = False, fail diff = True)
# --------------------------------------------------
# [28, 32, 33, 35, 42]
# i = 0, int1 = 28, int2 = 32 (fail order = False, fail diff = True)
# --------------------------------------------------
# [17, 21, 23, 26, 25, 26, 28]
# i = 0, int1 = 17, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [77, 81, 79, 80, 82, 83, 85, 83]
# i = 0, int1 = 77, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 91, 92, 89, 92, 92]
# i = 0, int1 = 87, int2 = 91 (fail order = False, fail diff = True)
# --------------------------------------------------
# [39, 43, 42, 43, 47]
# i = 0, int1 = 39, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [39, 43, 46, 44, 50]
# i = 0, int1 = 39, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 58, 59, 59, 61, 64]
# i = 0, int1 = 54, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [61, 65, 65, 66, 68, 65]
# i = 0, int1 = 61, int2 = 65 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 66, 68, 69, 70, 70, 70]
# i = 0, int1 = 62, int2 = 66 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 19, 19, 22, 24, 28]
# i = 0, int1 = 15, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 71, 73, 73, 74, 79]
# i = 0, int1 = 67, int2 = 71 (fail order = False, fail diff = True)
# --------------------------------------------------
# [75, 79, 83, 84, 86, 87, 89, 90]
# i = 0, int1 = 75, int2 = 79 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 17, 19, 20, 24, 26, 23]
# i = 0, int1 = 13, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [38, 42, 44, 47, 50, 54, 55, 55]
# i = 0, int1 = 38, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [22, 26, 30, 31, 33, 37]
# i = 0, int1 = 22, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 44, 47, 50, 52, 53, 57, 64]
# i = 0, int1 = 40, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [27, 31, 34, 41, 42]
# i = 0, int1 = 27, int2 = 31 (fail order = False, fail diff = True)
# --------------------------------------------------
# [44, 48, 50, 51, 56, 53]
# i = 0, int1 = 44, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 50, 51, 54, 55, 62, 63, 63]
# i = 0, int1 = 46, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 58, 61, 66, 67, 71]
# i = 0, int1 = 54, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [45, 49, 52, 54, 56, 62, 64, 70]
# i = 0, int1 = 45, int2 = 49 (fail order = False, fail diff = True)
# --------------------------------------------------
# [69, 74, 76, 79, 82, 79]
# i = 0, int1 = 69, int2 = 74 (fail order = False, fail diff = True)
# --------------------------------------------------
# [69, 75, 78, 81, 83, 85, 85]
# i = 0, int1 = 69, int2 = 75 (fail order = False, fail diff = True)
# --------------------------------------------------
# [45, 50, 51, 52, 55, 58, 62]
# i = 0, int1 = 45, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 36, 39, 41, 42, 49]
# i = 0, int1 = 29, int2 = 36 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 55, 54, 57, 59, 62, 65]
# i = 0, int1 = 50, int2 = 55 (fail order = False, fail diff = True)
# --------------------------------------------------
# [32, 37, 35, 38, 40, 42, 40]
# i = 0, int1 = 32, int2 = 37 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 57, 58, 57, 60, 61, 61]
# i = 0, int1 = 50, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 86, 89, 91, 89, 93]
# i = 0, int1 = 79, int2 = 86 (fail order = False, fail diff = True)
# --------------------------------------------------
# [30, 35, 33, 36, 41]
# i = 0, int1 = 30, int2 = 35 (fail order = False, fail diff = True)
# --------------------------------------------------
# [6, 13, 15, 16, 16, 18]
# i = 0, int1 = 6, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 25, 28, 31, 31, 32, 29]
# i = 0, int1 = 20, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 92, 93, 96, 96, 98, 98]
# i = 0, int1 = 87, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 20, 20, 23, 27]
# i = 0, int1 = 15, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [11, 17, 20, 23, 23, 28]
# i = 0, int1 = 11, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 59, 60, 64, 67]
# i = 0, int1 = 52, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [2, 8, 9, 10, 14, 15, 16, 13]
# i = 0, int1 = 2, int2 = 8 (fail order = False, fail diff = True)
# --------------------------------------------------
# [76, 81, 84, 85, 89, 91, 91]
# i = 0, int1 = 76, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 48, 51, 55, 57, 60, 63, 67]
# i = 0, int1 = 43, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [8, 14, 15, 17, 21, 27]
# i = 0, int1 = 8, int2 = 14 (fail order = False, fail diff = True)
# --------------------------------------------------
# [4, 9, 10, 16, 18, 19, 22, 25]
# i = 0, int1 = 4, int2 = 9 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 78, 84, 85, 87, 84]
# i = 0, int1 = 71, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [4, 11, 14, 20, 22, 22]
# i = 0, int1 = 4, int2 = 11 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 42, 47, 48, 49, 53]
# i = 0, int1 = 37, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [72, 79, 82, 87, 90, 97]
# i = 0, int1 = 72, int2 = 79 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 30, 29, 32, 35]
# i = 2, int1 = 29, int2 = 32 (fail order = True, fail diff = False)
# --------------------------------------------------
# [89, 88, 85, 83, 80, 79, 81, 81]
# i = 5, int1 = 79, int2 = 81 (fail order = True, fail diff = False)
# --------------------------------------------------
# [47, 46, 47, 46, 42]
# i = 1, int1 = 46, int2 = 47 (fail order = True, fail diff = False)
# --------------------------------------------------
# [59, 57, 55, 52, 49, 46, 48, 41]
# i = 5, int1 = 46, int2 = 48 (fail order = True, fail diff = False)
# --------------------------------------------------
# [71, 68, 68, 65, 64, 63, 61, 64]
# i = 1, int1 = 68, int2 = 68 (fail order = True, fail diff = True)
# --------------------------------------------------
# [92, 89, 86, 85, 84, 84, 84]
# i = 4, int1 = 84, int2 = 84 (fail order = True, fail diff = True)
# --------------------------------------------------
# [97, 96, 93, 93, 92, 91, 87]
# i = 2, int1 = 93, int2 = 93 (fail order = True, fail diff = True)
# --------------------------------------------------
# [76, 74, 71, 71, 70, 63]
# i = 2, int1 = 71, int2 = 71 (fail order = True, fail diff = True)
# --------------------------------------------------
# [38, 37, 33, 32, 29, 26, 25]
# i = 1, int1 = 37, int2 = 33 (fail order = False, fail diff = True)
# --------------------------------------------------
# [47, 46, 44, 40, 40]
# i = 2, int1 = 44, int2 = 40 (fail order = False, fail diff = True)
# --------------------------------------------------
# [99, 98, 94, 91, 88, 87, 84, 80]
# i = 1, int1 = 98, int2 = 94 (fail order = False, fail diff = True)
# --------------------------------------------------
# [86, 85, 82, 78, 77, 71]
# i = 2, int1 = 82, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 18, 17, 11, 10]
# i = 2, int1 = 17, int2 = 11 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 60, 58, 52, 53]
# i = 2, int1 = 58, int2 = 52 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 44, 37, 36, 35, 32, 32]
# i = 1, int1 = 44, int2 = 37 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 47, 45, 39, 35]
# i = 2, int1 = 45, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [74, 71, 70, 67, 60, 57, 51]
# i = 3, int1 = 67, int2 = 60 (fail order = False, fail diff = True)
# --------------------------------------------------
# [28, 29, 28, 25, 24, 23, 21, 24]
# i = 1, int1 = 29, int2 = 28 (fail order = True, fail diff = False)
# --------------------------------------------------
# [44, 46, 44, 41, 38, 35, 35]
# i = 1, int1 = 46, int2 = 44 (fail order = True, fail diff = False)
# --------------------------------------------------
# [70, 71, 70, 67, 64, 63, 59]
# i = 1, int1 = 71, int2 = 70 (fail order = True, fail diff = False)
# --------------------------------------------------
# [49, 52, 49, 46, 40]
# i = 1, int1 = 52, int2 = 49 (fail order = True, fail diff = False)
# --------------------------------------------------
# [88, 89, 87, 88, 87, 85]
# i = 1, int1 = 89, int2 = 87 (fail order = True, fail diff = False)
# --------------------------------------------------
# [44, 47, 45, 42, 43, 41, 43]
# i = 1, int1 = 47, int2 = 45 (fail order = True, fail diff = False)
# --------------------------------------------------
# [3, 5, 8, 7, 6, 3, 3]
# i = 2, int1 = 8, int2 = 7 (fail order = True, fail diff = False)
# --------------------------------------------------
# [85, 88, 91, 88, 85, 81]
# i = 2, int1 = 91, int2 = 88 (fail order = True, fail diff = False)
# --------------------------------------------------
# [55, 58, 55, 54, 57, 54, 47]
# i = 1, int1 = 58, int2 = 55 (fail order = True, fail diff = False)
# --------------------------------------------------
# [16, 18, 16, 15, 15, 14, 13]
# i = 1, int1 = 18, int2 = 16 (fail order = True, fail diff = False)
# --------------------------------------------------
# [75, 77, 75, 75, 78]
# i = 1, int1 = 77, int2 = 75 (fail order = True, fail diff = False)
# --------------------------------------------------
# [43, 46, 43, 40, 38, 38, 36, 36]
# i = 1, int1 = 46, int2 = 43 (fail order = True, fail diff = False)
# --------------------------------------------------
# [94, 95, 94, 91, 88, 88, 87, 83]
# i = 1, int1 = 95, int2 = 94 (fail order = True, fail diff = False)
# --------------------------------------------------
# [68, 70, 69, 67, 64, 64, 58]
# i = 1, int1 = 70, int2 = 69 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 53, 49, 47, 48]
# i = 1, int1 = 53, int2 = 49 (fail order = True, fail diff = True)
# --------------------------------------------------
# [43, 45, 42, 40, 38, 34, 32, 32]
# i = 1, int1 = 45, int2 = 42 (fail order = True, fail diff = False)
# --------------------------------------------------
# [43, 44, 43, 41, 39, 35, 32, 28]
# i = 1, int1 = 44, int2 = 43 (fail order = True, fail diff = False)
# --------------------------------------------------
# [55, 57, 53, 51, 44]
# i = 1, int1 = 57, int2 = 53 (fail order = True, fail diff = True)
# --------------------------------------------------
# [43, 45, 44, 37, 36, 34]
# i = 1, int1 = 45, int2 = 44 (fail order = True, fail diff = False)
# --------------------------------------------------
# [88, 90, 88, 85, 78, 76, 79]
# i = 1, int1 = 90, int2 = 88 (fail order = True, fail diff = False)
# --------------------------------------------------
# [57, 60, 57, 52, 50, 50]
# i = 1, int1 = 60, int2 = 57 (fail order = True, fail diff = False)
# --------------------------------------------------
# [43, 46, 40, 39, 38, 37, 36, 32]
# i = 1, int1 = 46, int2 = 40 (fail order = True, fail diff = True)
# --------------------------------------------------
# [95, 96, 89, 88, 81]
# i = 1, int1 = 96, int2 = 89 (fail order = True, fail diff = True)
# --------------------------------------------------
# [73, 73, 72, 71, 69, 68, 71]
# i = 0, int1 = 73, int2 = 73 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 43, 42, 41, 38, 38]
# i = 0, int1 = 43, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 23, 20, 17, 13]
# i = 0, int1 = 23, int2 = 23 (fail order = False, fail diff = True)
# --------------------------------------------------
# [42, 42, 40, 37, 35, 28]
# i = 0, int1 = 42, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 10, 8, 6, 9, 8]
# i = 0, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 40, 39, 41, 42]
# i = 0, int1 = 40, int2 = 40 (fail order = False, fail diff = True)
# --------------------------------------------------
# [6, 6, 4, 6, 5, 5]
# i = 0, int1 = 6, int2 = 6 (fail order = False, fail diff = True)
# --------------------------------------------------
# [31, 31, 30, 32, 30, 26]
# i = 0, int1 = 31, int2 = 31 (fail order = False, fail diff = True)
# --------------------------------------------------
# [35, 35, 34, 32, 34, 33, 32, 25]
# i = 0, int1 = 35, int2 = 35 (fail order = False, fail diff = True)
# --------------------------------------------------
# [27, 27, 25, 24, 24, 23, 21]
# i = 0, int1 = 27, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 54, 52, 49, 49, 48, 45, 47]
# i = 0, int1 = 54, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [56, 56, 56, 55, 55]
# i = 0, int1 = 56, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [51, 51, 48, 48, 47, 43]
# i = 0, int1 = 51, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 19, 19, 17, 11]
# i = 0, int1 = 19, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 54, 52, 49, 46, 42, 41]
# i = 0, int1 = 54, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [65, 65, 64, 60, 61]
# i = 0, int1 = 65, int2 = 65 (fail order = False, fail diff = True)
# --------------------------------------------------
# [24, 24, 23, 19, 16, 13, 13]
# i = 0, int1 = 24, int2 = 24 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 64, 60, 57, 53]
# i = 0, int1 = 64, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [88, 88, 87, 86, 83, 79, 73]
# i = 0, int1 = 88, int2 = 88 (fail order = False, fail diff = True)
# --------------------------------------------------
# [48, 48, 42, 39, 37, 36, 33]
# i = 0, int1 = 48, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [76, 76, 71, 70, 69, 68, 69]
# i = 0, int1 = 76, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [26, 26, 24, 19, 19]
# i = 0, int1 = 26, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 21, 18, 16, 11, 9, 5]
# i = 0, int1 = 21, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 46, 45, 43, 41, 40, 33, 26]
# i = 0, int1 = 46, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [60, 56, 55, 52, 51, 49, 51]
# i = 0, int1 = 60, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 50, 49, 47, 46, 46]
# i = 0, int1 = 54, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [42, 38, 35, 34, 32, 29, 25]
# i = 0, int1 = 42, int2 = 38 (fail order = False, fail diff = True)
# --------------------------------------------------
# [94, 90, 87, 86, 83, 81, 74]
# i = 0, int1 = 94, int2 = 90 (fail order = False, fail diff = True)
# --------------------------------------------------
# [58, 54, 53, 50, 49, 52, 50]
# i = 0, int1 = 58, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 48, 46, 44, 46, 49]
# i = 0, int1 = 52, int2 = 48 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 25, 23, 21, 18, 17, 20, 20]
# i = 0, int1 = 29, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 19, 18, 21, 19, 17, 13]
# i = 0, int1 = 23, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 33, 32, 34, 28]
# i = 0, int1 = 37, int2 = 33 (fail order = False, fail diff = True)
# --------------------------------------------------
# [82, 78, 75, 75, 73, 71, 68, 65]
# i = 0, int1 = 82, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [31, 27, 25, 23, 22, 19, 19, 22]
# i = 0, int1 = 31, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 51, 48, 48, 48]
# i = 0, int1 = 55, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [38, 34, 32, 29, 27, 27, 26, 22]
# i = 0, int1 = 38, int2 = 34 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 51, 50, 48, 48, 47, 42]
# i = 0, int1 = 55, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [81, 77, 75, 71, 70]
# i = 0, int1 = 81, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [43, 39, 37, 33, 31, 34]
# i = 0, int1 = 43, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 51, 50, 49, 48, 47, 43, 43]
# i = 0, int1 = 55, int2 = 51 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 15, 11, 9, 6, 2]
# i = 0, int1 = 19, int2 = 15 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 67, 66, 62, 61, 58, 52]
# i = 0, int1 = 71, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [41, 37, 36, 35, 30, 29, 26, 23]
# i = 0, int1 = 41, int2 = 37 (fail order = False, fail diff = True)
# --------------------------------------------------
# [53, 49, 43, 40, 37, 39]
# i = 0, int1 = 53, int2 = 49 (fail order = False, fail diff = True)
# --------------------------------------------------
# [88, 84, 82, 79, 74, 72, 70, 70]
# i = 0, int1 = 88, int2 = 84 (fail order = False, fail diff = True)
# --------------------------------------------------
# [97, 93, 87, 85, 81]
# i = 0, int1 = 97, int2 = 93 (fail order = False, fail diff = True)
# --------------------------------------------------
# [96, 92, 91, 84, 83, 78]
# i = 0, int1 = 96, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [98, 91, 90, 87, 85, 83, 84]
# i = 0, int1 = 98, int2 = 91 (fail order = False, fail diff = True)
# --------------------------------------------------
# [31, 24, 23, 21, 18, 17, 17]
# i = 0, int1 = 31, int2 = 24 (fail order = False, fail diff = True)
# --------------------------------------------------
# [70, 64, 63, 61, 57]
# i = 0, int1 = 70, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [61, 54, 52, 49, 46, 43, 37]
# i = 0, int1 = 61, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 17, 15, 13, 12, 11, 14, 13]
# i = 0, int1 = 23, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [49, 42, 39, 41, 39, 38, 40]
# i = 0, int1 = 49, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 26, 29, 27, 26, 26]
# i = 0, int1 = 33, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 31, 32, 30, 28, 25, 21]
# i = 0, int1 = 37, int2 = 31 (fail order = False, fail diff = True)
# --------------------------------------------------
# [70, 63, 60, 63, 60, 57, 56, 50]
# i = 0, int1 = 70, int2 = 63 (fail order = False, fail diff = True)
# --------------------------------------------------
# [56, 50, 48, 47, 44, 41, 41, 39]
# i = 0, int1 = 56, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [39, 34, 34, 33, 30, 28, 27, 29]
# i = 0, int1 = 39, int2 = 34 (fail order = False, fail diff = True)
# --------------------------------------------------
# [63, 56, 54, 54, 54]
# i = 0, int1 = 63, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [86, 80, 80, 77, 75, 74, 71, 67]
# i = 0, int1 = 86, int2 = 80 (fail order = False, fail diff = True)
# --------------------------------------------------
# [24, 18, 15, 14, 12, 11, 11, 6]
# i = 0, int1 = 24, int2 = 18 (fail order = False, fail diff = True)
# --------------------------------------------------
# [69, 64, 62, 60, 56, 55]
# i = 0, int1 = 69, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [82, 76, 72, 71, 69, 66, 63, 65]
# i = 0, int1 = 82, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [85, 78, 74, 72, 72]
# i = 0, int1 = 85, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [78, 72, 68, 67, 63]
# i = 0, int1 = 78, int2 = 72 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 74, 72, 70, 68, 64, 59]
# i = 0, int1 = 79, int2 = 74 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 47, 41, 40, 39, 36, 34, 31]
# i = 0, int1 = 52, int2 = 47 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 41, 40, 34, 31, 28, 31]
# i = 0, int1 = 46, int2 = 41 (fail order = False, fail diff = True)
# --------------------------------------------------
# [26, 19, 16, 14, 9, 9]
# i = 0, int1 = 26, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [72, 67, 62, 60, 56]
# i = 0, int1 = 72, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [85, 78, 72, 69, 68, 63]
# i = 0, int1 = 85, int2 = 78 (fail order = False, fail diff = True)
# --------------------------------------------------
# [83, 80, 77, 77, 74, 74]
# i = 2, int1 = 77, int2 = 77 (fail order = True, fail diff = True)
# --------------------------------------------------
# [54, 50, 48, 45, 41, 38, 34]
# i = 0, int1 = 54, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [60, 57, 59, 62, 60]
# i = 1, int1 = 57, int2 = 59 (fail order = True, fail diff = False)
# --------------------------------------------------
# [41, 38, 40, 47, 50, 52, 56]
# i = 1, int1 = 38, int2 = 40 (fail order = True, fail diff = False)
# --------------------------------------------------
# [74, 72, 73, 71, 74, 75, 77, 77]
# i = 1, int1 = 72, int2 = 73 (fail order = True, fail diff = False)
# --------------------------------------------------
# [67, 65, 63, 61, 60, 56, 55, 48]
# i = 4, int1 = 60, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [5, 9, 10, 11, 8, 10, 14]
# i = 0, int1 = 5, int2 = 9 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 70, 73, 74, 71, 75]
# i = 1, int1 = 70, int2 = 73 (fail order = True, fail diff = False)
# --------------------------------------------------
# [56, 56, 53, 55, 56, 60]
# i = 0, int1 = 56, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [74, 77, 78, 80, 81, 84, 84, 83]
# i = 5, int1 = 84, int2 = 84 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 62, 59, 57, 53]
# i = 0, int1 = 62, int2 = 62 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 85, 85, 88, 90, 94]
# i = 0, int1 = 79, int2 = 85 (fail order = False, fail diff = True)
# --------------------------------------------------
# [32, 30, 31, 33, 33, 34, 35, 35]
# i = 1, int1 = 30, int2 = 31 (fail order = True, fail diff = False)
# --------------------------------------------------
# [3, 7, 6, 9, 10, 12, 14, 14]
# i = 0, int1 = 3, int2 = 7 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 39, 36, 33, 33]
# i = 1, int1 = 39, int2 = 36 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 52, 47, 46, 45, 44, 44]
# i = 1, int1 = 52, int2 = 47 (fail order = True, fail diff = True)
# --------------------------------------------------
# [56, 52, 50, 49, 49, 47, 45, 46]
# i = 0, int1 = 56, int2 = 52 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 58, 61, 62, 64, 68]
# i = 0, int1 = 52, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [49, 49, 50, 52, 53, 55, 58, 58]
# i = 0, int1 = 49, int2 = 49 (fail order = False, fail diff = True)
# --------------------------------------------------
# [35, 32, 33, 37, 38, 37]
# i = 1, int1 = 32, int2 = 33 (fail order = True, fail diff = False)
# --------------------------------------------------
# [48, 45, 47, 49, 48, 50, 51]
# i = 1, int1 = 45, int2 = 47 (fail order = True, fail diff = False)
# --------------------------------------------------
# [8, 10, 10, 11, 11]
# i = 1, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 37, 38, 44, 50]
# i = 1, int1 = 37, int2 = 38 (fail order = True, fail diff = False)
# --------------------------------------------------
# [51, 58, 60, 63, 60, 67]
# i = 0, int1 = 51, int2 = 58 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 34, 37, 44, 46, 48, 51, 55]
# i = 2, int1 = 37, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [66, 69, 70, 73, 76, 79, 77, 83]
# i = 5, int1 = 79, int2 = 77 (fail order = True, fail diff = False)
# --------------------------------------------------
# [72, 72, 71, 70, 63, 62, 58]
# i = 0, int1 = 72, int2 = 72 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 62, 61, 60, 59, 56, 58, 51]
# i = 5, int1 = 56, int2 = 58 (fail order = True, fail diff = False)
# --------------------------------------------------
# [76, 70, 68, 64, 67]
# i = 0, int1 = 76, int2 = 70 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 44, 45, 48, 52, 54]
# i = 0, int1 = 40, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [61, 68, 70, 77, 79, 81, 81]
# i = 0, int1 = 61, int2 = 68 (fail order = False, fail diff = True)
# --------------------------------------------------
# [14, 12, 12, 14, 17, 19, 20, 21]
# i = 1, int1 = 12, int2 = 12 (fail order = True, fail diff = True)
# --------------------------------------------------
# [29, 33, 35, 36, 40]
# i = 0, int1 = 29, int2 = 33 (fail order = False, fail diff = True)
# --------------------------------------------------
# [90, 90, 88, 88, 86, 85, 84, 87]
# i = 0, int1 = 90, int2 = 90 (fail order = False, fail diff = True)
# --------------------------------------------------
# [19, 24, 27, 30, 37, 41]
# i = 0, int1 = 19, int2 = 24 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 63, 61, 57, 56, 55, 52, 53]
# i = 2, int1 = 61, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [75, 75, 72, 70, 64, 61, 64]
# i = 0, int1 = 75, int2 = 75 (fail order = False, fail diff = True)
# --------------------------------------------------
# [66, 69, 73, 74, 78]
# i = 1, int1 = 69, int2 = 73 (fail order = False, fail diff = True)
# --------------------------------------------------
# [56, 57, 54, 51, 51, 49, 45]
# i = 1, int1 = 57, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [56, 56, 57, 63, 66]
# i = 0, int1 = 56, int2 = 56 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 13, 16, 19, 21, 22, 22]
# i = 0, int1 = 9, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [65, 62, 63, 68, 68]
# i = 1, int1 = 62, int2 = 63 (fail order = True, fail diff = False)
# --------------------------------------------------
# [74, 72, 73, 80, 82, 84, 87, 89]
# i = 1, int1 = 72, int2 = 73 (fail order = True, fail diff = False)
# --------------------------------------------------
# [67, 62, 60, 58, 57, 59, 55]
# i = 0, int1 = 67, int2 = 62 (fail order = False, fail diff = True)
# --------------------------------------------------
# [60, 63, 61, 57, 52]
# i = 1, int1 = 63, int2 = 61 (fail order = True, fail diff = False)
# --------------------------------------------------
# [63, 67, 70, 77, 77]
# i = 0, int1 = 63, int2 = 67 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 68, 69, 68, 67, 64, 61, 62]
# i = 1, int1 = 68, int2 = 69 (fail order = True, fail diff = False)
# --------------------------------------------------
# [55, 59, 60, 60, 62, 60]
# i = 0, int1 = 55, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 59, 56, 54, 53, 53, 53]
# i = 0, int1 = 59, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [25, 25, 23, 25, 23, 20, 23]
# i = 0, int1 = 25, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 53, 52, 50, 50, 49, 47]
# i = 0, int1 = 59, int2 = 53 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 57, 59, 61, 63, 65, 70]
# i = 0, int1 = 57, int2 = 57 (fail order = False, fail diff = True)
# --------------------------------------------------
# [16, 16, 17, 18, 21, 21, 22, 22]
# i = 0, int1 = 16, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [36, 30, 29, 32, 33]
# i = 0, int1 = 36, int2 = 30 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 51, 49, 42, 40, 40]
# i = 2, int1 = 49, int2 = 42 (fail order = False, fail diff = True)
# --------------------------------------------------
# [34, 36, 39, 41, 42, 40, 40]
# i = 4, int1 = 42, int2 = 40 (fail order = True, fail diff = False)
# --------------------------------------------------
# [97, 90, 89, 87, 84, 82, 79, 79]
# i = 0, int1 = 97, int2 = 90 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 11, 9, 7, 4, 4]
# i = 0, int1 = 15, int2 = 11 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 25, 27, 24, 27, 30, 27]
# i = 0, int1 = 21, int2 = 25 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 30, 29, 28, 27, 30, 23]
# i = 1, int1 = 30, int2 = 29 (fail order = True, fail diff = False)
# --------------------------------------------------
# [18, 22, 26, 27, 30, 34]
# i = 0, int1 = 18, int2 = 22 (fail order = False, fail diff = True)
# --------------------------------------------------
# [35, 39, 42, 44, 45, 48, 52, 58]
# i = 0, int1 = 35, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [29, 30, 32, 33, 35, 36, 41, 42]
# i = 5, int1 = 36, int2 = 41 (fail order = False, fail diff = True)
# --------------------------------------------------
# [91, 87, 84, 82, 75, 74, 71, 70]
# i = 0, int1 = 91, int2 = 87 (fail order = False, fail diff = True)
# --------------------------------------------------
# [93, 93, 91, 93, 91, 90, 90]
# i = 0, int1 = 93, int2 = 93 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 64, 61, 60, 58, 53, 53]
# i = 0, int1 = 64, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [41, 44, 42, 44, 43, 42, 38]
# i = 1, int1 = 44, int2 = 42 (fail order = True, fail diff = False)
# --------------------------------------------------
# [56, 57, 55, 51, 49, 45]
# i = 1, int1 = 57, int2 = 55 (fail order = True, fail diff = False)
# --------------------------------------------------
# [67, 73, 76, 78, 79, 78]
# i = 0, int1 = 67, int2 = 73 (fail order = False, fail diff = True)
# --------------------------------------------------
# [79, 79, 81, 83, 87, 88, 88]
# i = 0, int1 = 79, int2 = 79 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 60, 57, 56, 54, 49]
# i = 1, int1 = 60, int2 = 57 (fail order = True, fail diff = False)
# --------------------------------------------------
# [34, 34, 35, 36, 38, 36, 38, 39]
# i = 0, int1 = 34, int2 = 34 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 63, 60, 54, 50]
# i = 2, int1 = 60, int2 = 54 (fail order = False, fail diff = True)
# --------------------------------------------------
# [88, 89, 86, 86, 89]
# i = 1, int1 = 89, int2 = 86 (fail order = True, fail diff = False)
# --------------------------------------------------
# [17, 16, 19, 23, 24, 27, 31]
# i = 1, int1 = 16, int2 = 19 (fail order = True, fail diff = False)
# --------------------------------------------------
# [91, 87, 86, 83, 80, 77, 73]
# i = 0, int1 = 91, int2 = 87 (fail order = False, fail diff = True)
# --------------------------------------------------
# [23, 21, 23, 24, 26, 29, 34]
# i = 1, int1 = 21, int2 = 23 (fail order = True, fail diff = False)
# --------------------------------------------------
# [53, 51, 48, 47, 45, 43, 39, 36]
# i = 5, int1 = 43, int2 = 39 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 20, 22, 26, 29, 30, 33, 31]
# i = 0, int1 = 13, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [91, 90, 87, 85, 81, 81]
# i = 3, int1 = 85, int2 = 81 (fail order = False, fail diff = True)
# --------------------------------------------------
# [15, 16, 15, 12, 11, 11, 8, 8]
# i = 1, int1 = 16, int2 = 15 (fail order = True, fail diff = False)
# --------------------------------------------------
# [79, 74, 71, 68, 67, 66, 62]
# i = 0, int1 = 79, int2 = 74 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 59, 58, 51, 45]
# i = 0, int1 = 59, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [38, 40, 45, 48, 51, 51]
# i = 1, int1 = 40, int2 = 45 (fail order = False, fail diff = True)
# --------------------------------------------------
# [54, 56, 54, 51, 49, 49, 48, 42]
# i = 1, int1 = 56, int2 = 54 (fail order = True, fail diff = False)
# --------------------------------------------------
# [32, 26, 25, 20, 19, 19]
# i = 0, int1 = 32, int2 = 26 (fail order = False, fail diff = True)
# --------------------------------------------------
# [36, 43, 46, 48, 48, 49]
# i = 0, int1 = 36, int2 = 43 (fail order = False, fail diff = True)
# --------------------------------------------------
# [9, 7, 7, 9, 12, 17]
# i = 1, int1 = 7, int2 = 7 (fail order = True, fail diff = True)
# --------------------------------------------------
# [17, 21, 24, 27, 32, 33, 35, 36]
# i = 0, int1 = 17, int2 = 21 (fail order = False, fail diff = True)
# --------------------------------------------------
# [51, 46, 44, 41, 39, 38, 34, 34]
# i = 0, int1 = 51, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [96, 96, 93, 90, 88, 85, 81, 83]
# i = 0, int1 = 96, int2 = 96 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 27, 30, 32, 33, 36, 41, 38]
# i = 0, int1 = 21, int2 = 27 (fail order = False, fail diff = True)
# --------------------------------------------------
# [46, 48, 45, 42, 41, 38, 34]
# i = 1, int1 = 48, int2 = 45 (fail order = True, fail diff = False)
# --------------------------------------------------
# [87, 84, 86, 84, 87, 90, 96]
# i = 1, int1 = 84, int2 = 86 (fail order = True, fail diff = False)
# --------------------------------------------------
# [80, 80, 81, 85, 90]
# i = 0, int1 = 80, int2 = 80 (fail order = False, fail diff = True)
# --------------------------------------------------
# [33, 38, 41, 40, 42, 44, 45, 44]
# i = 0, int1 = 33, int2 = 38 (fail order = False, fail diff = True)
# --------------------------------------------------
# [66, 60, 58, 54, 53]
# i = 0, int1 = 66, int2 = 60 (fail order = False, fail diff = True)
# --------------------------------------------------
# [26, 19, 16, 14, 10, 4]
# i = 0, int1 = 26, int2 = 19 (fail order = False, fail diff = True)
# --------------------------------------------------
# [40, 44, 47, 47, 49, 52, 56]
# i = 0, int1 = 40, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [71, 76, 77, 78, 79, 79]
# i = 0, int1 = 71, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [92, 92, 91, 92, 95, 93]
# i = 0, int1 = 92, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 70, 68, 63, 61, 60, 61]
# i = 2, int1 = 68, int2 = 63 (fail order = False, fail diff = True)
# --------------------------------------------------
# [32, 32, 34, 39, 39]
# i = 0, int1 = 32, int2 = 32 (fail order = False, fail diff = True)
# --------------------------------------------------
# [68, 71, 69, 67, 66, 61, 55]
# i = 1, int1 = 71, int2 = 69 (fail order = True, fail diff = False)
# --------------------------------------------------
# [57, 61, 68, 69, 71, 75]
# i = 0, int1 = 57, int2 = 61 (fail order = False, fail diff = True)
# --------------------------------------------------
# [73, 77, 79, 82, 84, 85, 87, 85]
# i = 0, int1 = 73, int2 = 77 (fail order = False, fail diff = True)
# --------------------------------------------------
# [7, 9, 10, 11, 14, 13, 16, 14]
# i = 4, int1 = 14, int2 = 13 (fail order = True, fail diff = False)
# --------------------------------------------------
# [15, 10, 12, 9, 8, 1]
# i = 0, int1 = 15, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [62, 63, 61, 54, 52]
# i = 1, int1 = 63, int2 = 61 (fail order = True, fail diff = False)
# --------------------------------------------------
# [31, 35, 36, 38, 39, 38, 39]
# i = 0, int1 = 31, int2 = 35 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 58, 60, 61, 62, 67, 65]
# i = 1, int1 = 58, int2 = 60 (fail order = True, fail diff = False)
# --------------------------------------------------
# [80, 76, 75, 74, 73, 71, 66, 68]
# i = 0, int1 = 80, int2 = 76 (fail order = False, fail diff = True)
# --------------------------------------------------
# [59, 64, 67, 71, 73, 80]
# i = 0, int1 = 59, int2 = 64 (fail order = False, fail diff = True)
# --------------------------------------------------
# [52, 46, 43, 43, 39]
# i = 0, int1 = 52, int2 = 46 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 62, 59, 55, 51]
# i = 0, int1 = 67, int2 = 62 (fail order = False, fail diff = True)
# --------------------------------------------------
# [55, 59, 62, 62, 65, 67, 68, 68]
# i = 0, int1 = 55, int2 = 59 (fail order = False, fail diff = True)
# --------------------------------------------------
# [92, 92, 89, 86, 85, 84, 83, 78]
# i = 0, int1 = 92, int2 = 92 (fail order = False, fail diff = True)
# --------------------------------------------------
# [37, 44, 46, 46, 47, 44]
# i = 0, int1 = 37, int2 = 44 (fail order = False, fail diff = True)
# --------------------------------------------------
# [21, 17, 13, 11, 11]
# i = 0, int1 = 21, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [11, 15, 16, 17, 20, 21, 24, 31]
# i = 0, int1 = 11, int2 = 15 (fail order = False, fail diff = True)
# --------------------------------------------------
# [95, 91, 89, 86, 89]
# i = 0, int1 = 95, int2 = 91 (fail order = False, fail diff = True)
# --------------------------------------------------
# [50, 50, 47, 44, 42, 45]
# i = 0, int1 = 50, int2 = 50 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 16, 13, 13, 10, 7, 5, 5]
# i = 0, int1 = 20, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [13, 20, 21, 22, 28]
# i = 0, int1 = 13, int2 = 20 (fail order = False, fail diff = True)
# --------------------------------------------------
# [57, 53, 51, 47, 46, 45, 48]
# i = 0, int1 = 57, int2 = 53 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 10, 8, 6, 4, 1, 3, 2]
# i = 0, int1 = 10, int2 = 10 (fail order = False, fail diff = True)
# --------------------------------------------------
# [64, 68, 71, 73, 74, 80, 86]
# i = 0, int1 = 64, int2 = 68 (fail order = False, fail diff = True)
# --------------------------------------------------
# [10, 16, 18, 16, 19, 19]
# i = 0, int1 = 10, int2 = 16 (fail order = False, fail diff = True)
# --------------------------------------------------
# [87, 90, 86, 84, 84]
# i = 1, int1 = 90, int2 = 86 (fail order = True, fail diff = True)
# --------------------------------------------------
# [29, 22, 20, 21, 19, 16]
# i = 0, int1 = 29, int2 = 22 (fail order = False, fail diff = True)
# --------------------------------------------------
# [2, 3, 5, 9, 15]
# i = 2, int1 = 5, int2 = 9 (fail order = False, fail diff = True)
# --------------------------------------------------
# [67, 70, 67, 66, 63, 63, 62]
# i = 1, int1 = 70, int2 = 67 (fail order = True, fail diff = False)
# --------------------------------------------------
# [66, 63, 67, 70, 72, 74, 75, 75]
# i = 1, int1 = 63, int2 = 67 (fail order = True, fail diff = True)
# --------------------------------------------------
# [98, 98, 96, 95, 94, 94]
# i = 0, int1 = 98, int2 = 98 (fail order = False, fail diff = True)
# --------------------------------------------------
# [41, 41, 37, 34, 33, 31, 31]
# i = 0, int1 = 41, int2 = 41 (fail order = False, fail diff = True)
# --------------------------------------------------
# [84, 84, 85, 89, 90, 91, 93, 97]
# i = 0, int1 = 84, int2 = 84 (fail order = False, fail diff = True)
# --------------------------------------------------
# [17, 17, 13, 12, 7]
# i = 0, int1 = 17, int2 = 17 (fail order = False, fail diff = True)
# --------------------------------------------------
# [20, 13, 10, 7, 7, 5, 5]
# i = 0, int1 = 20, int2 = 13 (fail order = False, fail diff = True)
# --------------------------------------------------
# [94, 96, 94, 93, 92, 89, 91]
# i = 1, int1 = 96, int2 = 94 (fail order = True, fail diff = False)
# --------------------------------------------------
# [38, 38, 41, 43, 47, 49, 51]
# i = 0, int1 = 38, int2 = 38 (fail order = False, fail diff = True)
# --------------------------------------------------
# 634

# %% [markdown]
# Correct answer !
